# %%
import os, sys
print(os.getcwd())
# Should show: /home/jiangwolin/rl4co/examples
import sys
sys.path.append("/home/jiangwolin/rl4co")
sys.path.insert(0, "/home/jiangwolin/rl4co")
sys.path.insert(0, "/home/jiangwolin") # Change to your own path
sys.path.append(os.path.abspath(".."))

# %load_ext autoreload
# %autoreload 2
from rl4co.envs.routing import PDPTWEnv, PDPTWGenerator
from rl4co.models.zoo import AttentionModel
from ortools_solver import darp_solver
from rl4co.models import AttentionModelPolicy, REINFORCE
from rl4co.models.rl import PPO
# Out:
# /Users/jiangwolin/Downloads/llm-darp-main/rl4co/examples

# %%
# !pwd
# Out:
# /Users/jiangwolin/Downloads/llm-darp-main/rl4co/examples

# %%
import torch
from rl4co.models.zoo import AttentionModelPolicy
from rl4co.envs.routing import PDPTWEnv

env = PDPTWEnv()

# Load checkpoint

env.reset(batch_size=[1])
# Out:
# TensorDict(
#     fields={
#         action_mask: Tensor(shape=torch.Size([1, 61]), device=cpu, dtype=torch.bool, is_shared=False),
#         capacity: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#         current_node: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.int64, is_shared=False),
#         current_time: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#         demand: Tensor(shape=torch.Size([1, 61]), device=cpu, dtype=torch.float32, is_shared=False),
#         done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#         h3_indices: Tensor(shape=torch.Size([1, 61]), device=cpu, dtype=torch.int64, is_shared=False),
#         i: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.int64, is_shared=False),
#         locs: Tensor(shape=torch.Size([1, 61, 2]), device=cpu, dtype=torch.float32, is_shared=False),
#         pending_count: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.int64, is_shared=False),
#         pending_schedule: Tensor(shape=torch.Size([1, 4]), device=cpu, dtype=torch.int64, is_shared=False),
#         previous_action: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.int64, is_shared=False),
#         terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#         time_windows: Tensor(shape=torch.Size([1, 61, 2]), device=cpu, dtype=torch.float32, is_shared=False),
#         travel_time_matrix: Tensor(shape=torch.Size([1, 207, 207]), device=cpu, dtype=torch.float32, is_shared=False),
#         used_capacity: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#         vehicle_capacity: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.int64, is_shared=False),
#         visited: Tensor(shape=torch.Size([1, 61]), device=cpu, dtype=torch.bool, is_shared=False)},
#     batch_size=torch.Size([1]),
#     device=None,
#     is_shared=False)

# %%
# Initiate untrained policy
untrained_policy = AttentionModelPolicy(env_name=env.name,
                                        embed_dim = 128,
                                        num_encoder_layers=3,
                                        num_heads=8)

# %%
device = 'cpu'

td_init = PDPTWEnv(generator_params={"num_customers":30}).reset(batch_size=[1]).to(device)

trained_policy = model_checkpoint.policy.to(device)

trained_out = trained_policy(td_init.clone(), phase="test", decode_type="sampling", return_actions=True)
untrained_out = untrained_policy(td_init.clone(), phase="test", decode_type="sampling", return_actions=True)

actions_trained = trained_out['actions'].cpu().detach()
actions_untrained = untrained_out["actions"].cpu().detach()

rewards_trained = trained_out['reward']
rewards_untrained = untrained_out['reward']

import matplotlib.pyplot as plt
for i, td in enumerate(td_init):
    fig, axs = plt.subplots(2,1, figsize=(11,20))
    env.render(td, actions_untrained[i], ax=axs[0]) 
    env.render(td, actions_trained[i], ax=axs[1])
    axs[0].set_title(f"Untrained | Cost = {-rewards_untrained[i].item():.3f}")
    axs[1].set_title(r"Trained $\pi_\theta$" + f"| Cost = {-rewards_trained[i].item():.3f}")

print(trained_out)
print(untrained_out)
# Out:
# {'reward': tensor([-705.5833]), 'log_likelihood': tensor([-14.8008], grad_fn=<SumBackward1>), 'actions': tensor([[35, 36,  3, 53,  1, 59,  2,  4, 55, 23, 43,  9, 57, 58, 56, 10, 45, 46,
#          41, 42,  0, 47, 21, 31, 49, 22, 60, 27, 19, 37, 20, 44,  7,  8,  0, 48,
#          25, 17, 33, 24, 18, 34,  5,  6,  0, 11, 29, 30, 39, 12, 54, 38, 51, 28,
#          52, 26,  0, 50, 13, 14,  0, 32, 15, 16,  0, 40,  0]])}
# {'reward': tensor([-1100.9000]), 'log_likelihood': tensor([-92.6753], grad_fn=<SumBackward1>), 'actions': tensor([[23,  9, 43, 55,  7,  5, 56,  0, 44,  0, 19, 27, 51, 20,  0, 35, 36,  0,
#          47, 48,  0, 59, 60,  0, 21, 22,  0, 29, 39, 30,  0, 17, 24,  0, 31, 32,
#           0, 49, 50,  0,  3,  1, 53,  2,  0, 40,  0, 13, 14,  0, 54,  0, 10,  0,
#          52,  0, 45,  6,  0, 37, 38,  0, 11, 12,  0,  4,  0, 33, 57, 18, 34,  0,
#          15, 16,  0, 25, 26,  0, 28,  0, 58,  0, 41, 42,  0, 46,  0,  8,  0]])}

# %%
device = 'cpu'

td_init = PDPTWEnv(generator_params={"num_customers":30}).reset(batch_size=[1]).to(device)

trained_policy = model_checkpoint.policy.to(device)

trained_out = trained_policy(td_init.clone(), phase="test", decode_type="sampling", return_actions=True)
untrained_out = untrained_policy(td_init.clone(), phase="test", decode_type="sampling", return_actions=True)
trained_out
# Out:
# {'reward': tensor([-524.9500]),
#  'log_likelihood': tensor([-19.8266], grad_fn=<SumBackward1>),
#  'actions': tensor([[29, 30, 27, 33, 28, 43, 37, 51, 38,  5, 45,  6, 41, 25, 11, 49, 42, 26,
#            1, 53,  2, 54, 23, 31, 32, 24, 55, 56,  0, 13, 14, 59, 34, 60, 15, 16,
#           47,  9, 10, 35, 19, 36, 20,  0, 44, 39, 17, 40, 46,  0,  7, 52,  3,  8,
#            4, 18, 21, 22,  0, 50, 57, 58,  0, 12, 48,  0]])}

# %%
from tqdm import tqdm

records = {}

for i in tqdm(range(10, 31, 5)):
    or_tools = []
    neural = []

    for j in tqdm(range(60)):  # Each instance run for j times
        td_init = PDPTWEnv(generator_params={"num_customers": i}).reset(batch_size=[1]).to(device)

        neural_out = trained_policy(
            td_init.clone(),
            phase="test",
            decode_type="greedy",
            return_actions=True,
        )
        print(neural_out)
        or_out = darp_solver(td_init, time_limit_seconds=1)

        # be careful: neural_out["reward"] is probably a tensor → convert to scalar if needed
        neural.append((- neural_out["reward"]).detach().cpu().item())
        or_tools.append(or_out["total_time"])

    # create the entry for this i
    records[f"{i} req"] = {
        "or_tools": or_tools,
        "neural": neural,
    }
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# {'reward': tensor([-286.9833]), 'log_likelihood': tensor([-1.2773], grad_fn=<SumBackward1>), 'actions': tensor([[ 3,  4, 13,  1, 14,  2, 11, 12,  0, 19,  5,  6, 20, 17,  9, 15,  7,  8,
#           0, 16,  0, 10,  0, 18,  0]])}
# {'reward': tensor([-326.1667]), 'log_likelihood': tensor([-2.3400], grad_fn=<SumBackward1>), 'actions': tensor([[17, 18, 15, 16, 13,  9, 10, 19,  5, 20,  6,  7,  1,  8,  2,  0, 11, 12,
#           0, 14,  3,  4,  0]])}
# {'reward': tensor([-264.0833]), 'log_likelihood': tensor([-1.6820], grad_fn=<SumBackward1>), 'actions': tensor([[11, 13, 14, 12, 19,  7,  5,  6,  3,  4, 15, 16,  0, 20,  8,  1,  2, 17,
#          18,  9, 10,  0]])}
# {'reward': tensor([-279.4333]), 'log_likelihood': tensor([-2.8719], grad_fn=<SumBackward1>), 'actions': tensor([[ 7, 11,  5,  8,  3,  6, 17,  4, 15,  9, 16, 10, 19, 13, 14, 20,  1,  2,
#           0, 12,  0, 18,  0]])}
# {'reward': tensor([-268.7500]), 'log_likelihood': tensor([-1.4378], grad_fn=<SumBackward1>), 'actions': tensor([[11, 15, 12, 16,  9, 10,  5, 17,  6,  1, 19,  3,  7, 20,  2,  4,  0, 13,
#          14, 18,  8,  0]])}
# {'reward': tensor([-232.4667]), 'log_likelihood': tensor([-2.0617], grad_fn=<SumBackward1>), 'actions': tensor([[13,  1, 15,  5,  9,  2, 16,  6,  7,  8,  0, 14,  3,  4,  0, 10, 17, 18,
#          19, 20, 11, 12,  0]])}
# {'reward': tensor([-285.2667]), 'log_likelihood': tensor([-2.5361], grad_fn=<SumBackward1>), 'actions': tensor([[15, 11,  5, 17,  6, 18,  1,  7,  3,  2,  9, 10, 19, 20,  0, 16, 12, 13,
#          14,  0,  8,  4,  0]])}
# {'reward': tensor([-242.5333]), 'log_likelihood': tensor([-2.0992], grad_fn=<SumBackward1>), 'actions': tensor([[ 9,  7, 10,  5,  1, 13, 14,  2, 15, 11, 17, 16, 12,  3,  4,  0,  8,  6,
#          19, 20, 18,  0]])}
# {'reward': tensor([-257.4000]), 'log_likelihood': tensor([-1.1373], grad_fn=<SumBackward1>), 'actions': tensor([[ 1,  2, 15,  5, 13,  9,  6, 10,  3,  4,  0, 16, 11, 14, 12,  7,  8, 17,
#          18,  0, 19, 20,  0]])}
# {'reward': tensor([-248.7500]), 'log_likelihood': tensor([-4.5805], grad_fn=<SumBackward1>), 'actions': tensor([[13, 14,  1,  3, 15, 19, 11,  2,  5,  7, 20, 12,  6,  8,  9, 10, 17, 18,
#           0,  4, 16,  0]])}
# {'reward': tensor([-262.2500]), 'log_likelihood': tensor([-1.4873], grad_fn=<SumBackward1>), 'actions': tensor([[ 7,  8,  5, 13, 11,  6, 14, 12,  9, 15, 10, 19,  3, 20,  4, 17, 18,  0,
#          16,  1,  2,  0]])}
# {'reward': tensor([-215.4667]), 'log_likelihood': tensor([-1.9343], grad_fn=<SumBackward1>), 'actions': tensor([[19, 15, 20, 16, 11,  9, 12,  1,  2,  7,  8,  0,  5,  6,  3, 13,  4, 14,
#          17, 18,  0, 10,  0]])}
# {'reward': tensor([-275.2167]), 'log_likelihood': tensor([-1.4905], grad_fn=<SumBackward1>), 'actions': tensor([[ 5, 15,  7,  6,  9, 13,  8, 14, 10, 19, 20,  3,  4, 11, 12, 17, 18,  1,
#           2,  0, 16,  0]])}
# {'reward': tensor([-245.]), 'log_likelihood': tensor([-0.7647], grad_fn=<SumBackward1>), 'actions': tensor([[ 5,  6, 11, 12,  9, 13, 17, 10, 18, 14, 15, 16, 19,  3,  4,  1,  2,  7,
#           8,  0, 20,  0]])}
# {'reward': tensor([-258.1833]), 'log_likelihood': tensor([-3.8628], grad_fn=<SumBackward1>), 'actions': tensor([[ 9, 13, 17,  1, 14, 10, 18,  0,  2,  7, 15,  3,  4, 19, 11, 20, 12,  0,
#           8,  5,  6,  0, 16,  0]])}
# {'reward': tensor([-240.]), 'log_likelihood': tensor([-1.5791], grad_fn=<SumBackward1>), 'actions': tensor([[19,  7,  8, 20,  9,  1,  2,  0, 15, 16,  3,  5,  4,  6, 17, 18, 13, 10,
#           0, 11, 12, 14,  0]])}
# {'reward': tensor([-240.8000]), 'log_likelihood': tensor([-0.8803], grad_fn=<SumBackward1>), 'actions': tensor([[19, 20, 11, 15, 12, 13,  1,  7,  2,  5,  6, 17,  9, 18, 10,  0, 16, 14,
#           3,  8,  4,  0]])}
# {'reward': tensor([-286.1667]), 'log_likelihood': tensor([-1.7700], grad_fn=<SumBackward1>), 'actions': tensor([[ 3,  7, 11,  4,  8, 15, 16,  1,  5,  2,  6,  0, 12, 19, 20, 17, 18,  9,
#          10,  0, 13, 14,  0]])}
# {'reward': tensor([-193.8500]), 'log_likelihood': tensor([-1.9297], grad_fn=<SumBackward1>), 'actions': tensor([[13,  7, 19,  8, 20, 15,  1,  2,  9, 10,  3,  4,  5,  6,  0, 14, 11, 12,
#          16, 17, 18,  0]])}
# {'reward': tensor([-339.6833]), 'log_likelihood': tensor([-1.7436], grad_fn=<SumBackward1>), 'actions': tensor([[ 5,  7,  8,  6, 15, 16, 11, 12, 17, 18,  1,  2, 19,  9, 10, 20,  0, 13,
#          14,  0,  3,  4,  0]])}
# {'reward': tensor([-239.2667]), 'log_likelihood': tensor([-1.5455], grad_fn=<SumBackward1>), 'actions': tensor([[ 9, 19, 10, 20,  3,  4,  5,  6,  0, 15,  1,  2, 16, 11, 13, 17, 14, 12,
#          18,  7,  8,  0]])}
# {'reward': tensor([-280.9167]), 'log_likelihood': tensor([-1.3649], grad_fn=<SumBackward1>), 'actions': tensor([[15, 16,  9, 10, 19, 11,  5, 20, 12,  6, 13, 14,  0, 17,  3,  4, 18,  1,
#           2,  0,  7,  8,  0]])}
# {'reward': tensor([-255.5333]), 'log_likelihood': tensor([-4.2556], grad_fn=<SumBackward1>), 'actions': tensor([[ 3, 19,  4, 17,  5, 15,  9, 13,  6, 10, 14,  7,  8,  1, 11,  2, 12,  0,
#          20, 18, 16,  0]])}
# {'reward': tensor([-271.6500]), 'log_likelihood': tensor([-1.1852], grad_fn=<SumBackward1>), 'actions': tensor([[ 5,  1,  9,  3,  6,  2, 15, 11, 16, 17, 19, 12, 18,  7,  8,  0, 10,  4,
#          13, 14, 20,  0]])}
# {'reward': tensor([-296.8000]), 'log_likelihood': tensor([-1.5803], grad_fn=<SumBackward1>), 'actions': tensor([[ 1,  2, 19, 13, 14,  5, 15,  6, 16,  3,  9,  4, 11, 10, 12,  0, 17, 18,
#           7,  8,  0, 20,  0]])}
# {'reward': tensor([-274.4000]), 'log_likelihood': tensor([-1.1043], grad_fn=<SumBackward1>), 'actions': tensor([[15, 19, 16, 20, 17, 18,  3,  4,  0,  5,  7,  9,  6,  1,  8, 10,  0,  2,
#          13, 14,  0, 11, 12,  0]])}
# {'reward': tensor([-228.8167]), 'log_likelihood': tensor([-0.7149], grad_fn=<SumBackward1>), 'actions': tensor([[ 3, 17,  4, 18, 15, 16,  5,  9, 10,  6,  0, 19,  1,  7,  2,  8, 13, 14,
#           0, 20, 11, 12,  0]])}
# {'reward': tensor([-294.7166]), 'log_likelihood': tensor([-0.4461], grad_fn=<SumBackward1>), 'actions': tensor([[15, 13, 16, 14, 19,  1,  9,  2, 10, 17, 18,  3,  4,  7,  5,  6,  8,  0,
#          11, 12,  0, 20,  0]])}
# {'reward': tensor([-215.5500]), 'log_likelihood': tensor([-3.5681], grad_fn=<SumBackward1>), 'actions': tensor([[13, 14,  7, 17,  9, 18,  8,  1,  2,  0,  5,  3, 19, 20,  0,  6,  4, 11,
#          12, 15, 16, 10,  0]])}
# {'reward': tensor([-315.7167]), 'log_likelihood': tensor([-1.3374], grad_fn=<SumBackward1>), 'actions': tensor([[19,  3,  4, 20,  5,  6, 15, 16,  7,  8,  9, 13, 10, 14,  0, 17, 18, 11,
#           1,  2,  0, 12,  0]])}
# {'reward': tensor([-251.9167]), 'log_likelihood': tensor([-1.3557], grad_fn=<SumBackward1>), 'actions': tensor([[ 3,  4, 13,  9, 17, 15, 10, 18,  5, 19,  1, 20,  2,  7,  8,  0, 14, 16,
#           6, 11, 12,  0]])}
# {'reward': tensor([-338.4000]), 'log_likelihood': tensor([-1.6670], grad_fn=<SumBackward1>), 'actions': tensor([[19, 20,  5, 13, 11,  6, 14,  1,  9,  7,  2,  8,  3,  4,  0, 12, 15, 10,
#          16, 17, 18,  0]])}
# {'reward': tensor([-243.5333]), 'log_likelihood': tensor([-2.2036], grad_fn=<SumBackward1>), 'actions': tensor([[11,  7, 15,  8, 13, 12, 14,  1,  2,  3,  4, 19, 20,  0, 16, 17, 18,  0,
#           9, 10,  5,  6,  0]])}
# {'reward': tensor([-248.4667]), 'log_likelihood': tensor([-2.5081], grad_fn=<SumBackward1>), 'actions': tensor([[19, 20,  7,  5,  8,  6, 11,  1,  2, 12, 13, 14,  0,  9, 10, 17, 18,  3,
#           4, 15, 16,  0]])}
# {'reward': tensor([-289.8333]), 'log_likelihood': tensor([-2.4836], grad_fn=<SumBackward1>), 'actions': tensor([[11, 12,  1,  3,  9,  7,  2,  8, 17,  5,  6, 13, 14, 15, 16,  0,  4, 10,
#          19, 20, 18,  0]])}
# {'reward': tensor([-289.4667]), 'log_likelihood': tensor([-0.7867], grad_fn=<SumBackward1>), 'actions': tensor([[11, 15, 16, 12,  3,  4, 17, 18,  0,  7,  8,  1,  9,  2,  5,  6, 19, 20,
#           0, 13, 14,  0, 10,  0]])}
# {'reward': tensor([-289.9500]), 'log_likelihood': tensor([-0.7167], grad_fn=<SumBackward1>), 'actions': tensor([[11, 12,  9, 10,  1,  2, 19, 20,  0,  3,  4,  7,  5, 13, 14,  6, 15, 16,
#          17, 18,  0,  8,  0]])}
# {'reward': tensor([-182.6500]), 'log_likelihood': tensor([-4.2970], grad_fn=<SumBackward1>), 'actions': tensor([[ 9,  7, 19, 13,  8, 20, 14,  5,  6, 17, 15, 16,  3,  1, 11,  2,  4, 12,
#           0, 10, 18,  0]])}
# {'reward': tensor([-311.3666]), 'log_likelihood': tensor([-0.8577], grad_fn=<SumBackward1>), 'actions': tensor([[17, 13,  7,  5, 15,  6,  1,  9, 10,  2,  3, 11,  4, 12, 19, 20,  0, 14,
#          16,  0, 18,  8,  0]])}
# {'reward': tensor([-324.3167]), 'log_likelihood': tensor([-1.5753], grad_fn=<SumBackward1>), 'actions': tensor([[15, 16,  9,  3, 10,  4,  7,  1,  2,  8, 13, 14,  0, 11, 12, 19, 20, 17,
#          18,  5,  6,  0]])}
# {'reward': tensor([-286.2000]), 'log_likelihood': tensor([-1.8087], grad_fn=<SumBackward1>), 'actions': tensor([[11,  3,  7,  4,  8, 19, 17,  5, 18,  6,  9, 10,  1, 15,  2,  0, 12, 16,
#           0, 20, 13, 14,  0]])}
# {'reward': tensor([-288.2667]), 'log_likelihood': tensor([-2.6007], grad_fn=<SumBackward1>), 'actions': tensor([[11,  5, 13,  6, 19, 20,  3,  1,  4, 17,  2,  7,  8,  0,  9, 12, 10, 14,
#          18, 15, 16,  0]])}
# {'reward': tensor([-282.4167]), 'log_likelihood': tensor([-1.3325], grad_fn=<SumBackward1>), 'actions': tensor([[ 9, 10,  3,  1,  4,  2, 13, 14, 17, 18, 11, 12, 15, 16,  0, 19,  7, 20,
#           0,  8,  5,  6,  0]])}
# {'reward': tensor([-289.2667]), 'log_likelihood': tensor([-1.0984], grad_fn=<SumBackward1>), 'actions': tensor([[13,  1,  5, 14,  2,  7, 15,  8, 19, 20,  0,  9,  6,  0, 10, 17,  3,  4,
#          16,  0, 11, 12,  0, 18,  0]])}
# {'reward': tensor([-267.1333]), 'log_likelihood': tensor([-0.4136], grad_fn=<SumBackward1>), 'actions': tensor([[ 1,  5,  2,  3,  6, 13, 11,  4, 14, 12,  7,  8, 19, 20, 17,  9, 10, 18,
#           0, 15, 16,  0]])}
# {'reward': tensor([-247.7500]), 'log_likelihood': tensor([-1.0583], grad_fn=<SumBackward1>), 'actions': tensor([[15, 16, 11,  5,  6, 12, 19, 13, 20, 14,  1,  2,  7,  8,  0,  9, 10,  3,
#           4, 17, 18,  0]])}
# {'reward': tensor([-217.4167]), 'log_likelihood': tensor([-1.9449], grad_fn=<SumBackward1>), 'actions': tensor([[ 9,  5,  6, 15,  1, 19,  7, 11,  2,  8, 12, 13, 14, 17, 18,  3,  4,  0,
#          10, 20,  0, 16,  0]])}
# {'reward': tensor([-215.2167]), 'log_likelihood': tensor([-2.5903], grad_fn=<SumBackward1>), 'actions': tensor([[17, 18,  9, 10,  7, 13, 11, 15,  1, 19,  8, 16,  2, 20,  0, 14, 12,  3,
#           4,  0,  5,  6,  0]])}
# {'reward': tensor([-275.0500]), 'log_likelihood': tensor([-1.9853], grad_fn=<SumBackward1>), 'actions': tensor([[ 3,  4,  7, 19,  9,  8, 10, 13, 11, 12,  5,  6, 15, 16,  1,  2,  0, 20,
#          17, 18, 14,  0]])}
# {'reward': tensor([-268.3167]), 'log_likelihood': tensor([-1.4962], grad_fn=<SumBackward1>), 'actions': tensor([[19,  3,  9,  4, 13, 14, 17, 15, 16,  0, 20, 18,  0,  1, 11,  2, 12,  7,
#           8,  0, 10,  5,  6,  0]])}
# {'reward': tensor([-163.]), 'log_likelihood': tensor([-0.3844], grad_fn=<SumBackward1>), 'actions': tensor([[11, 12,  1,  7,  2,  8, 19, 20,  0,  9, 13, 10, 15, 17, 16,  3,  4,  0,
#          14,  5,  6,  0, 18,  0]])}
# {'reward': tensor([-260.3000]), 'log_likelihood': tensor([-1.3352], grad_fn=<SumBackward1>), 'actions': tensor([[ 3, 17,  4, 18, 15,  5,  6, 16, 13, 14, 11, 19, 12, 20,  0,  9, 10,  7,
#           8,  1,  2,  0]])}
# {'reward': tensor([-280.9333]), 'log_likelihood': tensor([-0.5440], grad_fn=<SumBackward1>), 'actions': tensor([[11, 13, 12, 14, 15, 16, 17, 18,  7,  1,  8,  2,  5,  6,  3,  4,  0, 19,
#          20,  9, 10,  0]])}
# {'reward': tensor([-321.2000]), 'log_likelihood': tensor([-1.3625], grad_fn=<SumBackward1>), 'actions': tensor([[ 3,  4, 13, 14, 17, 18,  5,  6, 11, 12,  9,  7,  8,  0, 19,  1,  2, 15,
#          16,  0, 20,  0, 10,  0]])}
# {'reward': tensor([-297.7500]), 'log_likelihood': tensor([-1.9519], grad_fn=<SumBackward1>), 'actions': tensor([[15, 16, 11,  1, 12,  2, 13,  3, 14,  4,  7,  8,  0, 17, 18,  9, 10,  5,
#           6,  0, 19, 20,  0]])}
# {'reward': tensor([-229.1000]), 'log_likelihood': tensor([-1.2160], grad_fn=<SumBackward1>), 'actions': tensor([[19, 20, 17, 18, 13,  5,  7, 14,  8,  6,  0,  9, 10,  3, 15,  4,  1,  2,
#           0, 11, 12,  0, 16,  0]])}
# {'reward': tensor([-251.1667]), 'log_likelihood': tensor([-0.0867], grad_fn=<SumBackward1>), 'actions': tensor([[11, 12,  5,  6, 17, 18,  3,  7,  4,  8, 13, 14,  0,  9, 10,  1,  2, 15,
#          16, 19, 20,  0]])}
# {'reward': tensor([-229.4667]), 'log_likelihood': tensor([-2.0105], grad_fn=<SumBackward1>), 'actions': tensor([[15, 19, 20, 16, 17, 18,  5,  6,  0,  9,  1, 10,  2,  7,  8,  3, 11,  4,
#          12,  0, 13, 14,  0]])}
# {'reward': tensor([-288.3000]), 'log_likelihood': tensor([-0.6067], grad_fn=<SumBackward1>), 'actions': tensor([[15, 11,  1,  5, 13, 12,  2, 19, 20,  9, 10, 17, 18,  0, 16,  6,  3,  4,
#           7,  8,  0, 14,  0]])}
# {'reward': tensor([-345.3333]), 'log_likelihood': tensor([-3.8382], grad_fn=<SumBackward1>), 'actions': tensor([[ 1,  2, 13, 14,  7,  5,  8,  6,  9,  3,  4, 17, 18,  0, 19, 20, 11, 12,
#           0, 15, 16, 10,  0]])}
# 100%|██████████| 60/60 [01:19<00:00,  1.32s/it]
#  20%|██        | 1/5 [01:19<05:17, 79.45s/it]
# {'reward': tensor([-273.5334]), 'log_likelihood': tensor([-5.4631], grad_fn=<SumBackward1>), 'actions': tensor([[ 9, 11, 13, 17,  7, 25,  8, 15, 16,  5,  6,  0, 10, 12, 14, 18, 26, 19,
#          27,  3, 23, 20,  4, 24,  0,  1,  2, 29, 30, 28,  0, 21, 22,  0]])}
# {'reward': tensor([-289.9167]), 'log_likelihood': tensor([-1.9147], grad_fn=<SumBackward1>), 'actions': tensor([[21, 25, 22, 27, 19, 23, 26, 28, 24, 20, 11, 12,  3,  4,  9, 17, 10, 18,
#           0, 15,  7,  8, 16, 13, 14, 29,  5,  6,  0,  1,  2, 30,  0]])}
# {'reward': tensor([-399.8333]), 'log_likelihood': tensor([-4.8566], grad_fn=<SumBackward1>), 'actions': tensor([[13, 14, 27,  1,  2,  9,  5, 21, 11, 19,  6, 22, 12, 20, 23, 17, 15, 18,
#          16, 25, 26,  7,  8,  3,  4,  0, 28, 24,  0, 10, 29, 30,  0]])}
# {'reward': tensor([-335.2500]), 'log_likelihood': tensor([-3.4328], grad_fn=<SumBackward1>), 'actions': tensor([[19, 15, 13, 27, 20, 14, 28, 17, 18,  7, 21, 22,  0, 16, 23, 24, 29, 25,
#          26, 30,  0,  3, 11, 12,  4,  1,  5,  9,  2,  8,  0, 10,  6,  0]])}
# {'reward': tensor([-352.5000]), 'log_likelihood': tensor([-4.6437], grad_fn=<SumBackward1>), 'actions': tensor([[25, 29, 27, 30, 26,  9, 21, 10, 15,  7, 16,  8,  1,  5,  2, 19,  6,  0,
#           3, 17, 28,  4, 18, 13, 14,  0, 22, 23, 24, 11, 12,  0, 20,  0]])}
# {'reward': tensor([-344.8666]), 'log_likelihood': tensor([-3.7724], grad_fn=<SumBackward1>), 'actions': tensor([[19, 27, 20,  1, 15,  7,  2, 21, 13,  8, 17, 29, 22, 14, 18,  3,  5,  4,
#           6,  0, 28, 16, 11, 12,  0, 25, 26, 30,  9, 10, 23, 24,  0]])}
# {'reward': tensor([-382.8500]), 'log_likelihood': tensor([-3.6036], grad_fn=<SumBackward1>), 'actions': tensor([[ 5,  6, 19, 13, 20, 14, 11, 29, 23, 12, 24, 15, 16,  3, 25,  4,  9, 10,
#           0,  1,  2,  7,  8, 21, 22, 26, 17, 27, 18, 28,  0, 30,  0]])}
# {'reward': tensor([-381.3000]), 'log_likelihood': tensor([-2.5448], grad_fn=<SumBackward1>), 'actions': tensor([[23,  1, 21,  3,  2,  4, 19, 20, 25, 26, 27,  9,  5, 10, 28,  6, 15, 16,
#          29,  7,  8, 30,  0, 24, 22, 11, 12, 13, 14, 17, 18,  0]])}
# {'reward': tensor([-400.8167]), 'log_likelihood': tensor([-4.0431], grad_fn=<SumBackward1>), 'actions': tensor([[21, 22,  5,  3,  6,  4,  9, 11, 10, 12, 19, 20,  0, 13, 14, 15, 16,  7,
#          17, 25, 18,  8, 23,  1, 26, 24,  0, 27, 28,  0,  2, 29, 30,  0]])}
# {'reward': tensor([-312.7500]), 'log_likelihood': tensor([-5.0812], grad_fn=<SumBackward1>), 'actions': tensor([[ 3,  4, 21, 22, 25,  5,  6,  9,  1, 26, 23,  2, 19,  7, 11,  8, 20, 15,
#          16,  0, 10, 24, 17, 13, 18, 29, 14, 12,  0, 30,  0, 27, 28,  0]])}
# {'reward': tensor([-336.4167]), 'log_likelihood': tensor([-1.6989], grad_fn=<SumBackward1>), 'actions': tensor([[23, 15, 29,  5, 25,  3,  6, 26,  4, 17,  9, 18, 10, 27, 28, 21,  7, 22,
#           8,  0, 24, 30, 19, 20,  0, 16,  1, 13, 14,  2,  0, 11, 12,  0]])}
# {'reward': tensor([-421.2166]), 'log_likelihood': tensor([-9.7384], grad_fn=<SumBackward1>), 'actions': tensor([[ 7,  8,  3,  9, 15, 29,  4, 10, 19, 20, 25, 27, 26, 28, 23, 13,  1, 11,
#          21, 14,  2, 22, 12,  0, 16, 30, 24, 17, 18,  0,  5,  6,  0]])}
# {'reward': tensor([-363.7834]), 'log_likelihood': tensor([-4.4630], grad_fn=<SumBackward1>), 'actions': tensor([[19,  5, 20,  6, 23, 24,  1, 25,  7,  2,  8, 26,  3,  4,  0, 17, 27, 28,
#          18, 15,  9, 13, 29, 16, 10, 11, 12,  0, 30, 14,  0, 21, 22,  0]])}
# {'reward': tensor([-364.6500]), 'log_likelihood': tensor([-6.4439], grad_fn=<SumBackward1>), 'actions': tensor([[19, 20, 29, 13, 15, 14, 16, 11,  9, 12,  0, 30,  5,  6, 10,  1, 27,  2,
#          28,  0, 17,  3,  7,  8,  4, 25, 21, 26,  0, 18, 22, 23, 24,  0]])}
# {'reward': tensor([-453.1333]), 'log_likelihood': tensor([-1.5494], grad_fn=<SumBackward1>), 'actions': tensor([[ 1, 25,  2, 26, 27, 28,  0,  9,  7,  8, 10, 15, 19, 20, 16, 21, 22,  0,
#          17, 18,  3,  4, 29, 30, 11,  5, 13, 14,  6,  0, 12,  0, 23, 24,  0]])}
# {'reward': tensor([-456.5000]), 'log_likelihood': tensor([-3.4988], grad_fn=<SumBackward1>), 'actions': tensor([[27, 28, 21, 19, 20,  9, 13,  7, 14,  8, 29, 11, 30, 12,  0, 25, 23, 24,
#          26,  3,  4,  5,  6,  0, 22,  1, 17,  2, 18,  0, 10,  0, 15, 16,  0]])}
# {'reward': tensor([-436.7333]), 'log_likelihood': tensor([-2.0961], grad_fn=<SumBackward1>), 'actions': tensor([[21, 22, 17,  1, 23,  2, 24, 13, 29, 14, 30, 19, 15, 20, 11, 12,  0,  5,
#          25,  6, 26,  3,  4,  0,  9, 10, 27,  7, 28,  8, 18,  0, 16,  0]])}
# {'reward': tensor([-324.4000]), 'log_likelihood': tensor([-4.1468], grad_fn=<SumBackward1>), 'actions': tensor([[ 3, 29,  4, 17, 13,  5, 15,  6,  1,  9, 21, 23,  2, 10, 22, 24, 11, 12,
#           0, 30, 14, 16, 25, 19, 20,  0, 18,  7,  8, 27, 28,  0, 26,  0]])}
# {'reward': tensor([-402.8167]), 'log_likelihood': tensor([-1.8057], grad_fn=<SumBackward1>), 'actions': tensor([[ 5,  6,  7, 17, 15,  8, 25, 26, 29, 30,  3, 23,  4,  1, 11,  2, 13, 14,
#           9, 27, 10, 28,  0, 18, 16, 21, 22, 12,  0, 19, 20, 24,  0]])}
# {'reward': tensor([-366.8334]), 'log_likelihood': tensor([-4.1921], grad_fn=<SumBackward1>), 'actions': tensor([[19, 23, 20, 29, 17, 30, 18, 21,  9, 11, 27, 10, 28,  1,  2,  0, 24,  3,
#           7, 13,  4, 15,  5, 25, 16,  6, 26, 12,  0, 14, 22,  0,  8,  0]])}
# {'reward': tensor([-401.4166]), 'log_likelihood': tensor([-5.0399], grad_fn=<SumBackward1>), 'actions': tensor([[ 7,  8,  3, 15, 17,  4, 16,  9, 19, 20, 23, 10, 24,  0, 18,  1, 21, 25,
#          29, 26,  2, 11, 30,  0,  5,  6, 22, 27, 28, 13, 14,  0, 12,  0]])}
# {'reward': tensor([-450.3834]), 'log_likelihood': tensor([-4.5823], grad_fn=<SumBackward1>), 'actions': tensor([[ 9, 19, 10, 11, 12,  1, 21,  2,  7, 25,  8,  3, 23,  4, 24, 27, 28,  0,
#          20, 17, 18, 29, 30, 13, 15, 16, 14, 26,  0, 22,  5,  6,  0]])}
# {'reward': tensor([-323.9666]), 'log_likelihood': tensor([-5.7039], grad_fn=<SumBackward1>), 'actions': tensor([[ 7,  8,  5,  6, 15,  1, 23, 13,  2, 21, 14, 22, 27, 11,  9, 29, 10, 17,
#          18,  0, 16, 24, 28, 12, 30,  0, 19, 20, 25,  3, 26,  4,  0]])}
# {'reward': tensor([-302.9500]), 'log_likelihood': tensor([-5.9788], grad_fn=<SumBackward1>), 'actions': tensor([[ 3,  1, 13, 17, 19,  2, 15,  5,  6, 27, 28,  7, 11, 29, 12,  8,  9, 25,
#          26, 10,  0,  4, 14, 18, 20, 16, 30, 23, 24,  0, 21, 22,  0]])}
# {'reward': tensor([-441.0833]), 'log_likelihood': tensor([-3.8177], grad_fn=<SumBackward1>), 'actions': tensor([[21,  1,  9, 17, 29, 10,  0,  5, 22,  6, 19, 20, 11, 12, 27, 25, 26, 13,
#          14,  3,  4,  0,  2, 23, 24,  0,  7,  8, 28, 15, 16,  0, 30, 18,  0]])}
# {'reward': tensor([-326.3833]), 'log_likelihood': tensor([-4.2637], grad_fn=<SumBackward1>), 'actions': tensor([[11,  9, 29,  5, 10,  0, 12,  6, 30, 21, 23, 22, 24,  0, 27,  7, 19,  8,
#          17,  3, 25, 26,  4, 13, 14, 15, 16,  0, 20,  1,  2, 18,  0, 28,  0]])}
# {'reward': tensor([-414.8833]), 'log_likelihood': tensor([-7.6233], grad_fn=<SumBackward1>), 'actions': tensor([[15, 16, 13, 14, 11,  1, 19,  2, 20,  0,  7,  9,  8, 27, 28,  5, 17, 18,
#           6,  3,  4,  0, 23, 10, 21, 29, 24, 22,  0, 30, 25, 26,  0, 12,  0]])}
# {'reward': tensor([-411.7667]), 'log_likelihood': tensor([-2.4925], grad_fn=<SumBackward1>), 'actions': tensor([[ 9,  1, 10,  2, 15, 21, 17, 16, 27,  5, 28,  6, 13, 14,  0, 22, 18, 29,
#          23, 25, 30, 24, 19, 11, 12,  7,  8,  0,  3, 26,  0, 20,  0,  4,  0]])}
# {'reward': tensor([-341.8167]), 'log_likelihood': tensor([-5.4463], grad_fn=<SumBackward1>), 'actions': tensor([[ 3, 13,  1, 21,  9, 17, 14, 22,  2, 11, 29, 12,  5,  6, 30,  0,  4, 10,
#          18, 15, 25, 26,  0, 23,  7, 24,  8,  0, 16, 27, 28,  0, 19, 20,  0]])}
# {'reward': tensor([-372.7833]), 'log_likelihood': tensor([-3.6061], grad_fn=<SumBackward1>), 'actions': tensor([[ 1, 27, 25, 15,  2,  5,  6, 19, 20,  0, 28, 16,  9, 10, 21, 29,  7,  8,
#          23, 24,  3, 13, 11,  4, 14, 12,  0, 26, 22, 30,  0, 17, 18,  0]])}
# {'reward': tensor([-358.5667]), 'log_likelihood': tensor([-2.8093], grad_fn=<SumBackward1>), 'actions': tensor([[17, 18, 21,  1, 22,  7,  2,  8,  0, 11, 12,  5,  9,  6, 25,  3, 15, 26,
#           0, 19, 20, 16, 23, 29, 24, 30, 13, 14, 27, 28,  0,  4, 10,  0]])}
# {'reward': tensor([-401.6833]), 'log_likelihood': tensor([-4.3341], grad_fn=<SumBackward1>), 'actions': tensor([[ 7,  8, 17, 19, 18, 29,  5, 20, 30,  6, 23, 24,  0, 21, 22,  3, 25,  4,
#          13, 11, 26, 14, 12, 15, 27, 16, 28,  1,  2,  9, 10,  0]])}
# {'reward': tensor([-302.1167]), 'log_likelihood': tensor([-2.5338], grad_fn=<SumBackward1>), 'actions': tensor([[21,  9, 25, 10,  5,  6, 11, 29, 12, 30,  1,  2,  0, 22,  7, 26,  8, 13,
#          23, 14,  3, 24, 19,  4, 17, 27, 18, 28,  0, 20, 15, 16,  0]])}
# {'reward': tensor([-416.8666]), 'log_likelihood': tensor([-7.1701], grad_fn=<SumBackward1>), 'actions': tensor([[25, 26,  3,  1,  2, 17, 27, 18, 28, 23,  9, 24, 10,  5,  6,  0, 29, 15,
#          16,  7, 13, 19, 11, 20, 14,  8, 21, 22,  0,  4, 12,  0, 30,  0]])}
# {'reward': tensor([-434.4666]), 'log_likelihood': tensor([-4.4835], grad_fn=<SumBackward1>), 'actions': tensor([[ 5,  6,  1,  2, 13, 14, 25, 23, 11, 24, 12,  0,  9, 15, 10, 16, 21, 22,
#          19,  3,  4, 20, 27, 28, 26, 17, 18,  0,  7,  8, 29, 30,  0]])}
# {'reward': tensor([-388.1000]), 'log_likelihood': tensor([-2.8153], grad_fn=<SumBackward1>), 'actions': tensor([[23, 21, 19, 22, 20, 11, 27, 13, 12, 14, 28,  5,  6, 25, 26,  0, 24, 15,
#           3, 29, 16,  4,  7,  8, 17,  9, 10, 18,  0,  1,  2, 30,  0]])}
# {'reward': tensor([-375.6500]), 'log_likelihood': tensor([-3.2365], grad_fn=<SumBackward1>), 'actions': tensor([[25, 26, 23,  5, 11, 13, 29,  6, 12, 15, 30, 17, 18, 16, 21, 22,  3, 27,
#           4, 28,  1,  2, 19, 20,  7,  8,  0, 14,  9, 10,  0, 24,  0]])}
# {'reward': tensor([-373.3167]), 'log_likelihood': tensor([-2.9217], grad_fn=<SumBackward1>), 'actions': tensor([[11, 12,  1, 29,  2,  3,  4,  7, 23, 15, 21, 25, 24,  8, 22, 27, 17, 18,
#          28,  0,  9, 19, 10, 13, 14,  0, 30, 20, 26,  0,  5, 16,  6,  0]])}
# {'reward': tensor([-309.1333]), 'log_likelihood': tensor([-4.1275], grad_fn=<SumBackward1>), 'actions': tensor([[ 9, 10,  5, 23, 24,  6, 17, 25, 15, 21, 16, 22,  0,  7, 11, 29,  8, 30,
#          13, 18, 26, 14,  0, 12, 27,  3, 19, 28,  4, 20,  1,  2,  0]])}
# {'reward': tensor([-235.8667]), 'log_likelihood': tensor([-5.1338], grad_fn=<SumBackward1>), 'actions': tensor([[ 5,  6, 23, 19, 25,  3, 17,  4, 18, 21, 22,  7,  8, 29, 27, 30, 28,  0,
#          11, 26, 24, 20, 12, 13, 14,  0, 15,  9, 10,  1,  2,  0, 16,  0]])}
# {'reward': tensor([-368.5834]), 'log_likelihood': tensor([-2.4657], grad_fn=<SumBackward1>), 'actions': tensor([[25, 26, 17, 29, 13, 14, 11, 12,  1, 19, 23, 20,  2,  0, 18, 30, 27,  7,
#          24,  8,  0, 21,  5,  6,  9, 10, 28, 15, 16,  0, 22,  0,  3,  4,  0]])}
# {'reward': tensor([-299.6333]), 'log_likelihood': tensor([-5.4381], grad_fn=<SumBackward1>), 'actions': tensor([[ 1, 15, 23,  3,  2,  4, 24, 29, 30, 17,  5, 13, 18,  6, 14, 19, 20,  0,
#          21,  7,  9, 22,  0, 16, 11, 25, 12, 26,  0,  8, 10, 27, 28,  0]])}
# {'reward': tensor([-370.2833]), 'log_likelihood': tensor([-3.9318], grad_fn=<SumBackward1>), 'actions': tensor([[19,  1,  9, 29, 23,  2, 20, 24, 21, 22, 15, 25, 16, 11, 12, 13, 17, 14,
#          18,  0,  7, 10,  5, 27,  6,  3,  4, 26,  0, 30,  8, 28,  0]])}
# {'reward': tensor([-426.4500]), 'log_likelihood': tensor([-2.6545], grad_fn=<SumBackward1>), 'actions': tensor([[25,  1,  3, 23,  2, 24, 29,  7, 19, 15,  8, 16, 17, 18, 11, 12,  5,  6,
#           9, 10,  0, 26, 21, 13,  4, 20, 30, 14, 27, 28,  0, 22,  0]])}
# {'reward': tensor([-322.9167]), 'log_likelihood': tensor([-4.3644], grad_fn=<SumBackward1>), 'actions': tensor([[17, 29, 18, 30,  1, 23,  2,  3,  4, 25, 27, 15,  5,  7, 11,  6, 12,  0,
#          13, 14, 21, 19, 20,  9, 26, 28, 10, 16,  0, 24, 22,  0,  8,  0]])}
# {'reward': tensor([-404.2167]), 'log_likelihood': tensor([-2.8335], grad_fn=<SumBackward1>), 'actions': tensor([[17, 13, 11, 23, 14, 18, 12,  7,  1,  2, 27, 21,  8, 22, 29, 30,  5, 15,
#           6, 16,  9, 10,  0, 24, 28, 25, 26,  0,  3,  4, 19, 20,  0]])}
# {'reward': tensor([-351.3667]), 'log_likelihood': tensor([-4.1671], grad_fn=<SumBackward1>), 'actions': tensor([[ 1, 27,  5, 13, 25,  2, 14, 26, 23, 11, 12,  7, 17,  8, 18,  9, 21, 10,
#          15, 16,  0,  6, 19, 20, 22,  3,  4,  0, 28, 29, 30, 24,  0]])}
# {'reward': tensor([-423.9500]), 'log_likelihood': tensor([-3.3370], grad_fn=<SumBackward1>), 'actions': tensor([[ 3,  7,  4,  8, 27,  5,  6, 28, 21, 22, 17, 18,  0,  1, 11,  9, 19, 12,
#           2, 10, 13, 15, 23, 14, 16, 24,  0, 25, 29, 26,  0, 20,  0, 30,  0]])}
# {'reward': tensor([-451.7167]), 'log_likelihood': tensor([-3.6650], grad_fn=<SumBackward1>), 'actions': tensor([[21, 19, 22, 20, 25,  1, 26,  2,  3, 15, 16,  4,  0, 17, 27, 18, 13, 14,
#           7, 11,  8, 12,  0, 28,  9, 10,  5,  6,  0, 29, 30,  0, 23, 24,  0]])}
# {'reward': tensor([-273.3000]), 'log_likelihood': tensor([-4.7777], grad_fn=<SumBackward1>), 'actions': tensor([[13, 19,  3, 21,  4, 14, 29, 30,  7,  5,  8,  6, 27, 17,  9, 23, 28, 18,
#          24, 10,  0, 20, 22, 25, 26,  0,  1,  2, 15, 11, 16, 12,  0]])}
# {'reward': tensor([-430.1667]), 'log_likelihood': tensor([-1.9857], grad_fn=<SumBackward1>), 'actions': tensor([[29,  5,  9, 21, 10,  6, 25, 22, 26, 17, 13, 18, 14, 15, 16, 19,  7, 20,
#           3,  8,  4,  0, 30, 27, 11, 12,  1,  2,  0, 28, 23, 24,  0]])}
# {'reward': tensor([-322.3167]), 'log_likelihood': tensor([-3.4998], grad_fn=<SumBackward1>), 'actions': tensor([[25, 26,  1, 21, 17, 27,  2, 15,  7,  5,  6, 16, 13, 14,  0, 18, 19, 23,
#          20, 11, 12,  0, 28, 24, 29,  9,  3,  4,  8,  0, 22, 10,  0, 30,  0]])}
# {'reward': tensor([-370.6667]), 'log_likelihood': tensor([-4.6574], grad_fn=<SumBackward1>), 'actions': tensor([[ 1, 25,  2, 29, 30, 27, 21, 22,  3, 17,  9,  4, 18, 10, 15,  7, 13, 14,
#           8,  0, 26, 19, 28, 20, 16,  0, 23, 24,  5,  6,  0, 11, 12,  0]])}
# {'reward': tensor([-393.6500]), 'log_likelihood': tensor([-4.7354], grad_fn=<SumBackward1>), 'actions': tensor([[25, 26, 11, 21,  9, 12,  0, 22, 10,  7,  8, 15, 16,  0, 29,  1, 13, 14,
#           0,  3,  4, 27, 28,  5, 23,  6, 24, 17, 18,  0, 30,  2, 19, 20,  0]])}
# {'reward': tensor([-357.1333]), 'log_likelihood': tensor([-4.1691], grad_fn=<SumBackward1>), 'actions': tensor([[17, 18, 27, 29, 19, 15,  5, 16,  6,  9,  3, 10, 25,  4, 23, 24,  1,  2,
#           0, 21, 28, 22, 30, 20, 13, 11, 14, 12,  0,  7, 26,  8,  0]])}
# {'reward': tensor([-432.7333]), 'log_likelihood': tensor([-6.8081], grad_fn=<SumBackward1>), 'actions': tensor([[11, 12,  3,  7,  4,  9, 19, 17, 10, 20,  1,  5,  2, 27, 28,  0,  8, 13,
#          25, 14, 26,  6, 21, 29, 22, 30,  0, 23, 18, 24,  0, 15, 16,  0]])}
# {'reward': tensor([-378.1500]), 'log_likelihood': tensor([-4.6303], grad_fn=<SumBackward1>), 'actions': tensor([[15, 11,  9,  5, 10, 16,  0, 12,  6, 23, 13, 14, 24,  3,  4,  0, 17, 18,
#          27,  7,  1, 19,  2, 20, 21, 22,  0, 25, 26, 28,  8,  0, 29, 30,  0]])}
# {'reward': tensor([-396.8833]), 'log_likelihood': tensor([-5.4536], grad_fn=<SumBackward1>), 'actions': tensor([[27, 29, 15, 21,  5, 16, 30, 28,  6, 25,  3,  4, 26, 19, 17, 18,  7,  9,
#           8, 10, 23, 24,  0, 22, 20, 11, 12,  1,  2,  0, 13, 14,  0]])}
# {'reward': tensor([-394.7333]), 'log_likelihood': tensor([-3.4531], grad_fn=<SumBackward1>), 'actions': tensor([[15,  3, 25,  4, 26, 13, 21, 14, 22,  0, 16, 27,  1,  9, 19,  5, 28, 10,
#           2,  7,  8,  0, 17,  6, 18, 11, 29, 23, 12, 24,  0, 20,  0, 30,  0]])}
# {'reward': tensor([-383.4833]), 'log_likelihood': tensor([-2.7823], grad_fn=<SumBackward1>), 'actions': tensor([[ 3, 29, 23, 11,  4, 30,  5, 17,  1,  2, 25, 19, 20,  9, 13, 10, 14, 27,
#          28,  0, 24, 12, 21,  7,  8, 26, 15, 16,  0,  6, 18, 22,  0]])}
# 100%|██████████| 60/60 [01:21<00:00,  1.35s/it]
#  40%|████      | 2/5 [02:40<04:01, 80.42s/it]
# {'reward': tensor([-516.8667]), 'log_likelihood': tensor([-12.5156], grad_fn=<SumBackward1>), 'actions': tensor([[13, 11, 27, 14,  0, 21,  3, 17, 25, 15, 18, 26,  4, 31, 35, 36, 32, 23,
#          24, 19, 20,  0, 28, 12, 22, 16, 37, 38,  9,  1, 39,  2,  0, 29, 30,  0,
#          33, 34,  0,  5, 10,  6,  0,  7,  8,  0, 40,  0]])}
# {'reward': tensor([-518.6000]), 'log_likelihood': tensor([-4.5077], grad_fn=<SumBackward1>), 'actions': tensor([[35,  3, 37,  4, 36, 33, 31, 34, 32,  7,  9, 15,  8, 16, 21, 22,  0, 27,
#          19, 13, 14, 23, 11,  5,  1, 24,  6, 12,  2, 17, 18,  0, 28, 20, 29, 30,
#          39, 40, 25, 26,  0, 38, 10,  0]])}
# {'reward': tensor([-358.9167]), 'log_likelihood': tensor([-3.7328], grad_fn=<SumBackward1>), 'actions': tensor([[ 7,  9, 11, 39,  8, 10, 12, 40, 15, 37, 16, 38, 21, 22, 33, 34,  0, 35,
#           1, 19, 31, 13,  2, 29, 30,  0, 36, 32, 14,  3, 25, 27, 17, 26, 23,  4,
#          24,  0,  5, 20,  6, 28, 18,  0]])}
# {'reward': tensor([-446.5000]), 'log_likelihood': tensor([-2.6630], grad_fn=<SumBackward1>), 'actions': tensor([[21,  1, 27,  3,  2, 28,  9, 10, 39, 23, 25, 24, 26, 35, 36, 33, 34,  0,
#          22,  4, 17, 19, 18, 20, 37, 38, 29, 11, 13, 12, 14,  7,  8, 15, 16,  0,
#          30,  5,  6, 40,  0, 31, 32,  0]])}
# {'reward': tensor([-506.4333]), 'log_likelihood': tensor([-10.5455], grad_fn=<SumBackward1>), 'actions': tensor([[37, 13, 23, 19, 14, 24,  9, 10, 17, 18, 31, 21, 35, 36, 22, 33, 34,  5,
#          25,  6, 26,  0, 39, 38, 40, 15,  3, 32,  4, 29, 30,  0, 27, 28,  0, 20,
#          11,  7,  8, 12,  0, 16,  0,  1,  2,  0]])}
# {'reward': tensor([-500.4333]), 'log_likelihood': tensor([-6.9094], grad_fn=<SumBackward1>), 'actions': tensor([[33, 13, 14, 17,  9, 10, 18, 23, 31, 24, 29, 30,  0, 34, 19, 20,  1,  7,
#           8,  2, 11, 12, 32,  3,  4,  0,  5, 37,  6, 27, 39, 38, 40, 35, 28, 36,
#          15, 16,  0, 25, 26,  0, 21, 22,  0]])}
# {'reward': tensor([-357.9167]), 'log_likelihood': tensor([-5.7563], grad_fn=<SumBackward1>), 'actions': tensor([[ 7, 39,  5,  8, 11, 27, 35, 28,  6, 25, 37, 26, 31, 38, 33, 15, 19,  3,
#          20,  4, 29,  1,  2, 21, 22,  0, 40, 12, 36, 30, 23, 24,  0,  9, 17, 13,
#          10, 18, 14, 32, 34, 16,  0]])}
# {'reward': tensor([-422.5000]), 'log_likelihood': tensor([-7.2227], grad_fn=<SumBackward1>), 'actions': tensor([[ 3, 17, 39, 18,  4, 40, 19, 23, 20,  5,  6,  0, 33, 35, 34, 13, 15, 11,
#          14, 12, 31,  1,  9,  2, 10, 32, 25, 37, 29, 26, 38, 21,  7,  8, 24,  0,
#          36, 27, 28, 30, 22,  0, 16,  0]])}
# {'reward': tensor([-380.4167]), 'log_likelihood': tensor([-5.8582], grad_fn=<SumBackward1>), 'actions': tensor([[33, 13, 34, 14,  1, 17,  2,  5, 18, 39, 27,  6, 40,  3,  9, 31,  4, 15,
#          19, 16, 11, 25, 20, 12, 26, 29, 30,  0, 23, 24, 21, 22, 10, 37, 35, 38,
#          36,  0,  7, 28,  8, 32,  0]])}
# {'reward': tensor([-447.7667]), 'log_likelihood': tensor([-6.2956], grad_fn=<SumBackward1>), 'actions': tensor([[35, 25, 36, 31, 26, 32, 33, 15, 34, 16, 21,  9, 19, 20,  0,  5, 11,  6,
#          12,  7, 13,  8, 14, 22, 23, 24, 29,  3, 30,  0, 37, 38, 27, 28,  1,  2,
#           0, 10, 39, 40,  0,  4, 17, 18,  0]])}
# {'reward': tensor([-385.5167]), 'log_likelihood': tensor([-3.7651], grad_fn=<SumBackward1>), 'actions': tensor([[35, 11, 36, 12,  1,  2,  3,  4,  9, 17, 37,  7, 38, 18,  8, 15, 23, 24,
#          16,  0, 33, 34, 21, 25, 22, 31, 32,  0, 26, 39, 13,  5,  6, 40, 14, 27,
#          28, 10,  0, 19, 20,  0, 29, 30,  0]])}
# {'reward': tensor([-466.2167]), 'log_likelihood': tensor([-3.9956], grad_fn=<SumBackward1>), 'actions': tensor([[ 9,  3, 10,  4,  5,  6,  7, 39,  8, 19, 40, 20, 29, 30,  1, 21,  2, 22,
#           0, 33, 25, 17, 31, 27, 18, 32, 28, 37, 35, 36, 38,  0, 34, 11, 26, 12,
#          23, 24,  0, 13, 14, 15, 16,  0]])}
# {'reward': tensor([-397.6167]), 'log_likelihood': tensor([-10.7595], grad_fn=<SumBackward1>), 'actions': tensor([[11, 12, 19, 20, 27, 28, 25, 26,  7,  3, 35, 37, 23,  4, 15, 24,  0,  1,
#          21, 39,  2, 22, 40, 16,  0, 31, 29,  5,  6,  9, 10, 17, 33, 34, 18,  8,
#          36, 38,  0, 30, 32, 13, 14,  0]])}
# {'reward': tensor([-323.4333]), 'log_likelihood': tensor([-5.4444], grad_fn=<SumBackward1>), 'actions': tensor([[35, 27, 29, 31, 36,  5, 21, 15, 32,  6, 22,  1,  2, 37, 23,  7, 19, 38,
#          24,  8, 20,  0, 28, 30, 16, 39, 25,  9, 10, 11, 12,  3, 17,  4, 13, 14,
#           0, 26, 33, 34, 18,  0, 40,  0]])}
# {'reward': tensor([-438.0333]), 'log_likelihood': tensor([-4.3341], grad_fn=<SumBackward1>), 'actions': tensor([[17, 18, 29, 30, 31,  5,  6,  9, 33, 10, 34,  0, 37,  1, 38,  0,  3, 11,
#          21,  4, 25, 13, 27,  7, 39, 40,  8, 35, 19, 15, 16,  0,  2, 12, 22, 26,
#          28, 36, 20,  0, 23, 24, 14,  0, 32,  0]])}
# {'reward': tensor([-363.2833]), 'log_likelihood': tensor([-6.5629], grad_fn=<SumBackward1>), 'actions': tensor([[37, 19, 27, 33, 20, 38, 28,  7,  8, 23, 13, 39, 14, 40,  0, 31, 11, 17,
#          25, 26, 12, 21,  3, 22,  4,  5,  6, 15, 16,  9, 35, 10, 24,  1,  2,  0,
#          29, 30, 32, 18,  0, 34, 36,  0]])}
# {'reward': tensor([-427.8333]), 'log_likelihood': tensor([-5.6669], grad_fn=<SumBackward1>), 'actions': tensor([[21,  1, 19, 31,  2, 22, 32, 20, 17, 18, 37, 35, 36, 23, 11, 24, 12,  0,
#          33, 13, 27, 15,  9, 14, 16,  7, 39,  8, 40, 29, 25, 26,  0, 34, 28, 10,
#           5,  6,  0, 38, 30,  0,  3,  4,  0]])}
# {'reward': tensor([-417.8167]), 'log_likelihood': tensor([-5.6316], grad_fn=<SumBackward1>), 'actions': tensor([[33,  9, 37, 35, 31, 27, 32, 10, 38, 28,  5, 21, 25, 23,  6, 26, 24, 22,
#          13, 14,  0, 34, 19, 36,  1,  2, 20, 11, 17, 12,  3,  4,  0, 15, 16,  7,
#           8, 39, 40,  0, 18, 29, 30,  0]])}
# {'reward': tensor([-389.5334]), 'log_likelihood': tensor([-4.0522], grad_fn=<SumBackward1>), 'actions': tensor([[25, 26, 15, 17, 16, 31, 39, 32, 11, 12, 33, 34, 27,  3, 28,  4,  0, 18,
#          40, 37, 35, 19,  1, 29, 23, 30,  0, 38, 24,  9, 13, 14, 10,  5,  6, 21,
#          22,  0, 36, 20,  2,  7,  8,  0]])}
# {'reward': tensor([-375.4333]), 'log_likelihood': tensor([-2.7152], grad_fn=<SumBackward1>), 'actions': tensor([[15,  7, 11,  8, 12, 39,  5,  6, 31, 17, 18, 35, 36,  0, 16, 21, 13,  3,
#           4, 22, 25, 19, 37,  1, 38,  2, 20, 29, 27, 23, 40, 24, 32,  0, 14, 33,
#           9, 34, 10, 30, 28,  0, 26,  0]])}
# {'reward': tensor([-423.1166]), 'log_likelihood': tensor([-4.5743], grad_fn=<SumBackward1>), 'actions': tensor([[ 3,  5,  4,  6, 29, 11, 17,  1, 12,  0, 35, 36,  9, 31, 10, 32, 37, 33,
#          38, 34, 23, 15, 19,  7, 16, 21, 22,  8, 13, 14,  0, 18,  2, 27, 28, 24,
#          20,  0, 30, 25, 39, 26, 40,  0]])}
# {'reward': tensor([-351.2667]), 'log_likelihood': tensor([-10.4682], grad_fn=<SumBackward1>), 'actions': tensor([[13,  9, 35,  7, 19, 10,  8, 36, 27, 29, 28, 30, 15, 16,  0, 20, 17,  3,
#          33, 37,  4,  1,  5,  2, 38, 34,  0, 14,  6, 39, 11, 23, 25, 12, 26,  0,
#          18, 31, 32, 24,  0, 21, 22, 40,  0]])}
# {'reward': tensor([-442.2667]), 'log_likelihood': tensor([-7.5066], grad_fn=<SumBackward1>), 'actions': tensor([[ 9,  7,  8, 35, 27, 37, 17,  3, 28, 18,  4, 33, 21, 15, 19, 16, 29, 11,
#          12, 30, 13, 14,  0, 10, 38, 31, 32, 25, 26,  1,  2,  0, 36, 39, 20, 23,
#          24,  0, 40,  0,  5, 22, 34,  0,  6,  0]])}
# {'reward': tensor([-465.1834]), 'log_likelihood': tensor([-5.7131], grad_fn=<SumBackward1>), 'actions': tensor([[39, 29, 30, 40, 31, 32, 19, 15,  3, 16,  4,  9, 10, 35, 36,  0, 11, 25,
#          12,  1,  7, 27, 23, 17,  2,  8, 28, 20, 33, 37, 13, 38, 34, 14,  0, 26,
#          24, 18, 21, 22,  0,  5,  6,  0]])}
# {'reward': tensor([-413.3667]), 'log_likelihood': tensor([-7.6455], grad_fn=<SumBackward1>), 'actions': tensor([[21, 13, 31, 22, 14, 32, 27, 28,  1,  2, 11,  3,  4,  9, 10, 29, 35, 30,
#          15, 16,  0, 25,  7, 17, 39,  8, 19, 18, 40, 20,  5, 37,  6, 12, 38,  0,
#          26, 23, 24,  0, 33, 34,  0, 36,  0]])}
# {'reward': tensor([-457.7666]), 'log_likelihood': tensor([-7.2825], grad_fn=<SumBackward1>), 'actions': tensor([[ 1,  2, 21,  7, 37, 17,  3, 29,  4, 19, 30, 13, 25, 11, 14, 12, 23, 24,
#           0, 22, 38, 26,  9, 10, 39,  5, 15,  6, 35, 31, 32,  0, 18,  8, 20, 33,
#          34,  0, 40, 16,  0, 27, 36, 28,  0]])}
# {'reward': tensor([-528.9167]), 'log_likelihood': tensor([-7.8193], grad_fn=<SumBackward1>), 'actions': tensor([[17, 29, 18, 11, 35, 31, 12,  9, 19, 10,  5,  1, 33,  2, 34, 21, 39, 40,
#          22, 37,  7,  8,  3,  4, 13, 14,  0, 23, 25, 24, 15, 32, 16, 20,  6,  0,
#          30, 26, 36,  0, 27, 38, 28,  0]])}
# {'reward': tensor([-473.0667]), 'log_likelihood': tensor([-7.2032], grad_fn=<SumBackward1>), 'actions': tensor([[ 9,  1, 10,  2, 25, 26,  3,  4, 27, 21, 15, 39, 22, 16, 23, 13, 14, 29,
#          30, 33, 37, 34, 38, 31, 32,  5,  6,  0, 28, 19, 20,  0, 40, 24,  0,  7,
#           8, 11, 35, 36, 12,  0, 17, 18,  0]])}
# {'reward': tensor([-445.6166]), 'log_likelihood': tensor([-9.6583], grad_fn=<SumBackward1>), 'actions': tensor([[ 1, 15, 11, 19, 16,  2, 12, 20,  5, 31,  6, 39, 27, 29, 25, 40, 26, 33,
#          34, 17, 18,  3,  4,  0, 13, 23, 21, 14, 22, 24, 32, 28,  7, 30,  8, 35,
#          36,  0, 37, 38,  0,  9, 10,  0]])}
# {'reward': tensor([-420.8500]), 'log_likelihood': tensor([-11.3946], grad_fn=<SumBackward1>), 'actions': tensor([[25, 31, 26,  1,  2,  3, 21, 29, 19, 30,  0,  4, 20, 27, 28,  9, 23, 33,
#          37, 10,  7, 35,  8,  5,  6,  0, 39, 11, 15, 40,  0, 32, 22, 16, 17, 18,
#          34, 24, 38, 36,  0, 12, 13, 14,  0]])}
# {'reward': tensor([-375.6000]), 'log_likelihood': tensor([-8.7572], grad_fn=<SumBackward1>), 'actions': tensor([[15, 33, 19,  3, 35, 11, 29,  4, 37,  1, 38,  2, 23, 24, 39, 40, 31, 27,
#          28,  0, 16, 34, 20, 30, 36, 12, 21, 17, 22, 18,  0,  9,  5,  6, 25, 26,
#          32,  0, 10,  7, 13,  8,  0, 14,  0]])}
# {'reward': tensor([-421.9667]), 'log_likelihood': tensor([-6.7530], grad_fn=<SumBackward1>), 'actions': tensor([[13, 14, 37,  9,  3,  5,  7,  4, 10,  6, 19, 20, 17, 18,  0, 39, 35, 21,
#          40, 33, 15, 27, 16, 28, 11, 25, 12, 26,  0, 38,  8, 22, 31, 32,  0,  1,
#           2, 36, 23, 24,  0, 34, 29, 30,  0]])}
# {'reward': tensor([-454.6667]), 'log_likelihood': tensor([-7.6150], grad_fn=<SumBackward1>), 'actions': tensor([[27, 21, 17, 18, 11, 28, 12,  1, 31, 32,  2,  7, 25, 29,  8, 30,  0,  9,
#          35,  5, 19, 13, 23,  6, 33, 24, 34, 26,  0, 22, 36, 20, 39,  3,  4, 37,
#          38, 15, 16,  0, 10, 14, 40,  0]])}
# {'reward': tensor([-463.3500]), 'log_likelihood': tensor([-6.5050], grad_fn=<SumBackward1>), 'actions': tensor([[39, 31, 21, 19, 13,  1,  3, 37, 14, 17,  2,  4, 18, 33, 25, 29, 26, 34,
#           9, 27, 10, 23, 28,  5,  6, 24,  0, 32, 20, 38,  7,  8, 11, 15, 16,  0,
#          22, 35, 36, 30,  0, 40,  0, 12,  0]])}
# {'reward': tensor([-436.4000]), 'log_likelihood': tensor([-4.3809], grad_fn=<SumBackward1>), 'actions': tensor([[29, 30, 19,  5, 13, 11,  6, 12, 14, 25, 26,  9, 21, 22, 10,  3,  7,  4,
#           8,  0, 31, 37, 15, 32, 17, 33, 16, 23, 27, 24, 28, 35, 36,  0, 20, 38,
#          39,  1,  2,  0, 34, 18, 40,  0]])}
# {'reward': tensor([-419.1833]), 'log_likelihood': tensor([-2.3847], grad_fn=<SumBackward1>), 'actions': tensor([[ 7, 11,  5, 19, 37, 21,  3,  6, 20, 38,  4, 15, 29, 31,  1, 39,  2, 40,
#          17, 18, 27, 28,  0,  8, 12, 16, 23, 35, 25, 24, 26, 36,  0, 22, 13, 30,
#          32, 14, 33, 34,  9, 10,  0]])}
# {'reward': tensor([-475.0833]), 'log_likelihood': tensor([-4.2770], grad_fn=<SumBackward1>), 'actions': tensor([[33, 29, 21, 30,  0, 22, 17, 37, 25,  7, 19, 38,  8,  3,  4,  9, 27, 10,
#          15, 16,  0, 34, 23,  5, 24,  6, 28,  0, 31, 35, 36, 32, 18, 26, 13, 39,
#          14,  0, 11, 20, 12, 40,  1,  2,  0]])}
# {'reward': tensor([-408.7500]), 'log_likelihood': tensor([-4.2170], grad_fn=<SumBackward1>), 'actions': tensor([[ 9,  7, 15, 21,  8, 16, 22, 23, 29, 24, 33, 30,  0, 10,  3,  5,  1, 31,
#           2, 13, 11, 14, 25, 12, 34, 19, 20, 39, 40,  0, 35, 36,  6, 37, 26, 38,
#          17, 18,  0,  4, 32,  0, 27, 28,  0]])}
# {'reward': tensor([-429.3500]), 'log_likelihood': tensor([-8.6031], grad_fn=<SumBackward1>), 'actions': tensor([[ 7, 13,  3, 15,  8, 14, 16,  4, 39, 21, 17, 22, 18,  1,  2, 35, 11, 12,
#          27, 19, 23, 28,  0,  5, 33, 40,  6,  9, 10,  0, 34, 31, 32,  0, 37, 25,
#          36, 29, 26, 38, 30,  0, 20, 24,  0]])}
# {'reward': tensor([-381.1500]), 'log_likelihood': tensor([-5.1244], grad_fn=<SumBackward1>), 'actions': tensor([[23, 31, 24, 32,  1, 29, 15, 35, 19, 27,  2, 20,  9, 10,  5, 13,  6, 33,
#          14, 34,  0, 30, 39, 28, 40,  7, 11,  8, 12, 25,  3, 37,  4,  0, 17, 21,
#          18, 22, 38,  0, 16, 36,  0, 26,  0]])}
# {'reward': tensor([-351.4833]), 'log_likelihood': tensor([-7.7695], grad_fn=<SumBackward1>), 'actions': tensor([[21, 33, 29, 15, 27,  1, 28,  2, 13, 31, 35,  5, 32, 36,  6, 25,  9, 19,
#          10, 11, 20,  7,  8, 23, 24,  0, 30, 39, 40,  3,  4, 37, 38,  0, 34, 22,
#          16, 14, 17, 18,  0, 26, 12,  0]])}
# {'reward': tensor([-464.1500]), 'log_likelihood': tensor([-8.9629], grad_fn=<SumBackward1>), 'actions': tensor([[17,  5,  3,  7,  6,  4, 21, 37, 27, 22, 25, 26,  0, 18, 38, 31, 32,  0,
#          11,  8, 33, 19, 12,  1,  2,  0, 34, 29,  9, 23, 15, 39, 10, 28,  0, 30,
#          24, 35, 13, 40, 16, 14,  0, 20, 36,  0]])}
# {'reward': tensor([-393.1167]), 'log_likelihood': tensor([-6.8807], grad_fn=<SumBackward1>), 'actions': tensor([[29,  7, 30,  8,  9,  1,  3, 39, 27, 28,  2,  4, 10, 40, 15, 19, 35, 16,
#          11, 12, 31, 37, 25, 23, 32,  5, 33,  6, 34,  0, 20, 36, 17, 18, 26, 24,
#           0, 21, 22,  0, 38, 13, 14,  0]])}
# {'reward': tensor([-387.1500]), 'log_likelihood': tensor([-7.8263], grad_fn=<SumBackward1>), 'actions': tensor([[21,  5, 27,  1,  6, 22,  3, 28,  2,  4, 11, 17,  7,  9, 33,  8, 34, 39,
#          29, 30, 13, 40, 14,  0, 31, 35, 12, 18, 32, 36, 10, 15, 37, 16, 38, 19,
#          25, 20, 23, 24,  0, 26,  0]])}
# {'reward': tensor([-513.6667]), 'log_likelihood': tensor([-4.6645], grad_fn=<SumBackward1>), 'actions': tensor([[15, 13, 29, 33,  7, 25, 21, 34,  8, 26, 22, 39, 31, 32, 40,  1,  2,  9,
#          19, 10, 23, 20,  5,  3,  4,  0, 14, 16, 30, 17, 37, 38, 18, 27, 28,  6,
#           0, 11, 12, 24,  0, 35, 36,  0]])}
# {'reward': tensor([-447.5167]), 'log_likelihood': tensor([-5.9454], grad_fn=<SumBackward1>), 'actions': tensor([[ 1, 31,  3, 25,  2, 32,  4, 26, 23, 29, 30, 21, 19, 39, 27, 28, 20, 40,
#           0,  9, 10, 11,  5, 15,  6, 16, 33, 34,  7,  8, 17, 37, 24, 18, 22,  0,
#          35, 13, 12, 14,  0, 36, 38,  0]])}
# {'reward': tensor([-427.0167]), 'log_likelihood': tensor([-5.2167], grad_fn=<SumBackward1>), 'actions': tensor([[11,  3, 37, 12, 38,  4, 21, 22,  5,  1, 27,  9,  2, 10,  0, 19, 23, 20,
#          17, 35, 18, 36, 29, 30,  7, 15,  8, 25, 26,  0, 33, 31, 32, 39, 40, 16,
#          28,  6,  0, 13, 14,  0, 24, 34,  0]])}
# {'reward': tensor([-426.2667]), 'log_likelihood': tensor([-4.4410], grad_fn=<SumBackward1>), 'actions': tensor([[17, 25, 33, 26, 18, 31, 32, 21, 22,  3, 23, 35, 36,  4, 39, 40,  0, 34,
#          27,  5,  7, 15,  6, 16,  8,  9, 19, 10, 37, 38,  1, 29, 30,  2,  0, 13,
#          28, 14, 20,  0, 11, 12, 24,  0]])}
# {'reward': tensor([-443.0000]), 'log_likelihood': tensor([-4.0500], grad_fn=<SumBackward1>), 'actions': tensor([[29, 39, 30, 40, 25, 19, 20,  1,  2,  0, 15, 37, 21,  3, 27, 38, 22,  4,
#          33, 13, 31,  5, 17,  7,  6, 35, 36, 26,  0, 16, 14, 34, 32,  8, 18,  9,
#          10,  0, 28, 23, 24, 11, 12,  0]])}
# {'reward': tensor([-497.1167]), 'log_likelihood': tensor([-5.1124], grad_fn=<SumBackward1>), 'actions': tensor([[39, 13, 31,  7, 21, 32, 22,  8,  5,  3, 27,  4, 17,  1, 25,  2, 33, 26,
#           0, 40, 14, 34, 29, 30,  0, 15, 23, 16, 28, 11, 19, 12, 18, 37, 38,  0,
#          24,  6,  9, 35, 10, 20,  0, 36,  0]])}
# {'reward': tensor([-372.2833]), 'log_likelihood': tensor([-9.5081], grad_fn=<SumBackward1>), 'actions': tensor([[15, 29,  5,  7,  6, 33, 34, 11, 37, 23, 12, 24, 19, 39, 20, 13, 14, 31,
#          21, 32, 25, 22, 26,  1,  2,  0, 30, 38, 27, 28, 40, 17, 18,  0, 16,  8,
#          35,  3,  9, 36, 10,  4,  0]])}
# {'reward': tensor([-377.1500]), 'log_likelihood': tensor([-6.8868], grad_fn=<SumBackward1>), 'actions': tensor([[ 9, 37, 11,  3,  1, 23,  7,  2, 12, 21, 29, 22, 30, 39, 40, 13, 14, 33,
#          31, 32,  0, 35, 36, 25, 26, 34,  0, 10, 38,  4, 24,  8, 19,  5,  6, 27,
#          17, 18,  0, 15, 16, 20, 28,  0]])}
# {'reward': tensor([-403.2333]), 'log_likelihood': tensor([-6.9252], grad_fn=<SumBackward1>), 'actions': tensor([[11, 12, 33,  7,  8,  3, 27, 29, 28,  4, 31, 32,  0, 25, 21, 17,  1, 37,
#          15,  2, 34, 30,  0, 19, 20, 22, 35, 13, 36, 14,  0, 26, 18, 16,  5, 39,
#          40,  6,  0,  9, 23, 10, 24,  0, 38,  0]])}
# {'reward': tensor([-447.9667]), 'log_likelihood': tensor([-5.3319], grad_fn=<SumBackward1>), 'actions': tensor([[ 1,  7, 27,  2, 28, 13, 17,  5,  3, 14,  4,  6, 29, 30,  0, 39, 33, 40,
#          34, 25, 26,  9, 31, 32, 18, 10, 11, 15, 12, 16,  0,  8, 37, 19, 20, 35,
#          36, 23, 24,  0, 21, 22, 38,  0]])}
# {'reward': tensor([-338.6166]), 'log_likelihood': tensor([-11.2056], grad_fn=<SumBackward1>), 'actions': tensor([[39, 23,  9, 40, 37, 11, 13, 31, 33, 19, 10,  3,  4,  1,  2, 15, 16, 21,
#          22,  0, 24, 38, 12, 32, 14, 34, 27, 35, 28, 29, 36, 30,  0, 25, 20, 26,
#          17, 18,  5,  7,  8,  6,  0]])}
# {'reward': tensor([-439.6000]), 'log_likelihood': tensor([-3.5931], grad_fn=<SumBackward1>), 'actions': tensor([[23, 35, 21, 27, 29,  1,  3, 39,  2, 33, 34, 40, 15, 13, 16, 14,  9,  5,
#           6, 10, 31, 25, 26,  7,  8, 11, 12,  0, 24, 30, 28,  4, 19, 20, 32,  0,
#          36, 22, 37, 17, 18,  0, 38,  0]])}
# {'reward': tensor([-420.1500]), 'log_likelihood': tensor([-2.3108], grad_fn=<SumBackward1>), 'actions': tensor([[ 7, 27,  8,  1, 11, 28,  2, 37, 38, 25,  5, 33, 29, 13,  6, 14,  0, 21,
#          22, 19, 15, 20, 16, 39, 40,  0, 12,  9, 17, 10, 18,  3, 35,  4, 26, 34,
#          30,  0, 31, 32, 23, 24, 36,  0]])}
# {'reward': tensor([-425.9167]), 'log_likelihood': tensor([-6.5937], grad_fn=<SumBackward1>), 'actions': tensor([[ 9, 19, 10, 31, 21,  7, 22, 13,  8,  0, 11,  5, 15,  1, 16, 12,  2, 39,
#          40, 35, 33,  3, 27, 34, 28, 23, 17, 24,  4, 18, 29, 37, 25, 26, 38,  0,
#           6, 36, 14,  0, 20, 32, 30,  0]])}
# {'reward': tensor([-330.8334]), 'log_likelihood': tensor([-8.5058], grad_fn=<SumBackward1>), 'actions': tensor([[37,  3,  5, 35, 36,  4, 25,  7, 17, 26, 18,  0, 38,  6,  8, 33, 15, 34,
#          16, 39, 40, 13, 14,  0,  1,  2, 19, 11, 23, 20, 12,  9, 10,  0, 24, 29,
#          21, 27, 28, 22, 30,  0, 31, 32,  0]])}
# {'reward': tensor([-407.3834]), 'log_likelihood': tensor([-5.5402], grad_fn=<SumBackward1>), 'actions': tensor([[37, 19, 17, 35, 21, 11, 39, 12, 40, 27, 28,  7, 25,  9,  8, 10, 31,  5,
#           6,  0, 20, 38, 22, 36, 26, 15, 23, 16, 24,  0, 18, 29, 33, 30,  3,  4,
#           0, 34, 13,  1, 14,  0,  2, 32,  0]])}
# 100%|██████████| 60/60 [01:22<00:00,  1.37s/it]
#  60%|██████    | 3/5 [04:02<02:42, 81.31s/it]
# {'reward': tensor([-449.7500]), 'log_likelihood': tensor([-12.9091], grad_fn=<SumBackward1>), 'actions': tensor([[39, 15,  9, 37, 10, 47,  1, 49, 48,  2, 31, 11, 12, 13, 14,  0, 40, 16,
#          38, 50, 32, 41, 19, 33, 23,  3, 20, 34, 27, 24,  4, 28,  0, 25, 26,  5,
#          45, 35,  6, 29, 30, 21, 42,  7, 17, 22,  8, 18,  0, 43, 36,  0, 44,  0,
#          46,  0]])}
# ...
# {'reward': tensor([-696.9833]), 'log_likelihood': tensor([-14.9878], grad_fn=<SumBackward1>), 'actions': tensor([[25, 57, 21,  5, 58, 22,  6, 43, 55, 11, 33,  9,  3, 59, 12, 10, 60,  4,
#          15, 16, 39, 49, 41, 40, 31, 19, 32,  7,  8, 37, 38, 45, 46, 29, 30, 53,
#          54,  0, 26, 44, 34, 23, 24, 35, 20,  0, 56, 51, 52, 27, 17, 18,  0, 42,
#           1, 13,  2, 14,  0, 50,  0, 47, 48, 28,  0, 36,  0]])}
# {'reward': tensor([-599.3167]), 'log_likelihood': tensor([-11.9646], grad_fn=<SumBackward1>), 'actions': tensor([[25, 26, 59, 57, 21, 41, 23,  9, 42, 13, 35, 24, 10, 36, 55, 56,  3, 51,
#          52,  4,  0, 31, 45,  7, 46, 32,  8, 22, 29, 14, 17, 43, 19, 27, 18, 33,
#          47, 34, 48,  0,  1, 53, 49, 37, 39, 15,  5,  2, 40, 30, 11, 12, 44, 20,
#          28,  0, 54, 38, 16, 58,  0, 50,  6, 60,  0]])}
# {'reward': tensor([-689.9833]), 'log_likelihood': tensor([-16.1026], grad_fn=<SumBackward1>), 'actions': tensor([[39, 55, 29, 43, 44, 30, 59, 41, 33, 21, 19, 15, 16, 57, 58, 13, 14, 23,
#          24, 45, 46,  0, 40, 56, 31, 32,  5, 27,  6, 35, 47, 36, 48,  0, 53, 54,
#          49, 50,  0, 42, 22,  7, 25,  1,  2, 17, 37, 18, 28,  0,  3, 34,  4, 51,
#          11, 12,  0,  9, 10, 26,  0, 60, 20,  0,  8, 52, 38,  0]])}
# {'reward': tensor([-562.2333]), 'log_likelihood': tensor([-11.4195], grad_fn=<SumBackward1>), 'actions': tensor([[ 7, 57, 19,  1, 11, 31, 59, 60,  0, 58,  8, 20,  2, 21, 22,  9, 41, 55,
#          53, 10, 56, 13, 45, 14,  0,  3, 47, 35, 39,  4, 29, 27, 43, 30, 28, 44,
#          42, 54,  0, 12, 32, 25, 26, 15, 17, 16, 18, 49, 50, 46,  5,  6,  0, 36,
#          48, 40, 23, 37, 51, 24, 52, 33, 34,  0, 38,  0]])}
# {'reward': tensor([-443.4500]), 'log_likelihood': tensor([-17.5680], grad_fn=<SumBackward1>), 'actions': tensor([[27, 17, 33, 25, 57, 18, 34, 26, 58, 55,  3, 47, 56,  4, 48, 41, 45, 31,
#          32, 53, 54,  0, 28, 43, 37,  1, 38,  2,  9,  7, 29, 59, 21, 19,  8, 42,
#          35, 39, 46, 36, 40,  0, 15, 49, 16, 10, 60, 23,  5, 24, 11,  6, 13, 51,
#          14, 52,  0, 44, 30, 20, 22,  0, 50, 12,  0]])}
# {'reward': tensor([-551.5500]), 'log_likelihood': tensor([-12.9647], grad_fn=<SumBackward1>), 'actions': tensor([[29, 30, 41, 35, 42, 36,  5, 43,  6,  0, 49, 33, 51, 50, 34, 23, 24, 21,
#           9,  1, 10, 22,  2, 44,  0, 57, 25, 58, 39,  7, 15, 27, 55,  8, 26, 59,
#          37, 53, 19, 60, 17, 18, 13, 14, 45, 46,  0, 52, 28, 47,  3,  4, 48, 31,
#          32,  0, 40, 56, 16, 20, 38, 54, 11, 12,  0]])}
# {'reward': tensor([-651.2333]), 'log_likelihood': tensor([-14.4992], grad_fn=<SumBackward1>), 'actions': tensor([[35, 27, 39, 37, 17, 57,  7, 15,  8, 16, 45, 11, 12, 43, 44, 29, 30, 53,
#          54,  3,  4,  0, 51, 36, 40, 52, 58, 21, 23,  1, 59, 33, 49, 60,  2, 19,
#          34, 20, 41, 42, 25,  5, 13, 26,  6,  9, 10,  0, 18, 24, 50, 46, 55, 56,
#           0, 38, 47, 22, 48,  0, 28, 31, 32, 14,  0]])}
# {'reward': tensor([-610.9333]), 'log_likelihood': tensor([-17.0094], grad_fn=<SumBackward1>), 'actions': tensor([[35,  9,  3, 53, 36, 37, 19,  4, 38, 41,  7, 17, 18,  8,  5, 43, 15,  6,
#          23, 49, 16, 24, 55, 51, 52, 11, 12, 25, 26, 31, 32,  0, 10, 54, 20, 21,
#          44, 57, 13, 22, 14, 59, 45, 27, 60, 46, 28,  0, 42, 58, 39, 40,  0, 47,
#          50, 48,  0, 56, 33, 29, 30,  0, 34,  0,  1,  2,  0]])}
# {'reward': tensor([-509.6166]), 'log_likelihood': tensor([-10.1204], grad_fn=<SumBackward1>), 'actions': tensor([[33, 13, 57, 25, 26, 14, 27, 15, 51, 45, 28, 52, 16, 46, 59, 49,  3,  4,
#          17,  7, 18,  8, 23, 39, 55, 24, 56, 43, 47, 44,  0, 34, 58, 40, 48, 11,
#          12,  0,  1,  5, 37,  9, 38,  2,  6, 31, 53, 32, 29, 41, 35, 30, 36, 21,
#          22,  0, 19, 20, 50,  0, 10, 54, 60, 42,  0]])}
# {'reward': tensor([-516.9667]), 'log_likelihood': tensor([-10.9700], grad_fn=<SumBackward1>), 'actions': tensor([[29, 39, 30, 40, 35, 15, 36, 13, 53, 49, 54, 14, 31,  1, 59, 51, 32,  2,
#          52,  0, 19, 20, 11,  3, 41, 21, 12,  4, 42, 23, 17, 27, 37, 43, 18, 24,
#          45, 50, 46, 60,  0, 25, 33, 55, 34, 26,  5, 47, 57,  7,  6, 16, 48,  8,
#           0, 44, 56,  9, 10, 58,  0, 22, 38, 28,  0]])}
# {'reward': tensor([-509.9167]), 'log_likelihood': tensor([-13.8459], grad_fn=<SumBackward1>), 'actions': tensor([[43,  3,  1, 17, 53,  7,  2, 33, 27, 37, 38, 28,  5,  6, 11, 57, 12, 58,
#           9, 51, 10, 52,  0,  4, 18, 54,  8, 25, 19, 31, 20, 59, 32, 60,  0, 44,
#          34, 55, 39, 35, 45, 41, 15, 13, 47, 16, 46, 48, 14, 49, 26, 50,  0, 29,
#          30, 21, 22,  0, 56, 40, 42, 23, 24,  0, 36,  0]])}
# {'reward': tensor([-530.3333]), 'log_likelihood': tensor([-11.1697], grad_fn=<SumBackward1>), 'actions': tensor([[37, 51,  1, 13, 27, 53, 35, 39, 28,  2, 14, 36, 54, 47, 57, 48, 17,  3,
#          41,  4, 42, 43, 44,  0, 38, 52, 15, 31, 59, 16, 32, 60, 49, 21, 45, 22,
#          19,  5,  9, 33,  6, 34, 58,  7, 11,  8, 25, 18, 26,  0, 40, 55, 56, 10,
#          23, 29, 24, 12,  0, 50, 20, 30,  0, 46,  0]])}
# {'reward': tensor([-646.5499]), 'log_likelihood': tensor([-14.0283], grad_fn=<SumBackward1>), 'actions': tensor([[57,  7, 55, 25,  3, 51, 31, 37, 38, 43,  4, 49, 50, 11, 12, 39, 40, 59,
#          60, 41, 42, 29, 30,  0, 47, 48,  9, 32, 52, 10, 27,  5,  1,  6,  0, 58,
#           8, 26, 56, 45, 44, 33, 34, 46, 15, 35, 19, 17, 53, 16, 20, 23, 24, 21,
#          13, 14, 22,  0, 18, 36, 54,  0, 28,  0,  2,  0]])}
# {'reward': tensor([-589.5167]), 'log_likelihood': tensor([-14.2072], grad_fn=<SumBackward1>), 'actions': tensor([[57, 21, 49, 29, 51, 22, 50, 30, 52, 37, 35, 33, 25, 38, 36,  0, 58, 11,
#          31,  3, 47, 45, 15, 27, 48,  4, 16, 26, 34, 59, 41, 53,  9,  5, 42, 17,
#          10,  6,  1,  2,  0, 32, 46, 28, 13,  7,  8, 43, 19, 39, 23, 20, 54, 60,
#          18,  0, 12, 14, 44, 55, 56,  0, 40, 24,  0]])}
# {'reward': tensor([-610.6833]), 'log_likelihood': tensor([-10.4784], grad_fn=<SumBackward1>), 'actions': tensor([[ 5,  6, 17, 55, 18,  3,  9, 13,  4,  7, 51, 21,  8, 37, 35, 59, 36, 60,
#          47, 48,  0, 25, 41, 29,  1, 43,  2, 30, 10, 23, 15, 45, 31, 16, 46, 38,
#          53, 54,  0, 56, 42, 44, 19, 27, 20, 24, 22, 52,  0, 26, 11, 33, 34, 12,
#          39, 49, 57, 50, 40, 14, 58,  0, 28,  0, 32,  0]])}
# {'reward': tensor([-579.7666]), 'log_likelihood': tensor([-10.5073], grad_fn=<SumBackward1>), 'actions': tensor([[ 1,  7, 17, 19, 39, 41,  2,  8, 20, 40, 49, 27, 25, 55, 26,  5, 47,  6,
#          48, 35, 15, 31, 36, 13, 16, 32, 14,  0, 11, 42, 18,  9, 12, 10, 43, 21,
#          59, 22, 51, 37, 38,  3, 57, 33,  4, 34,  0, 53, 54, 58,  0, 56, 28, 60,
#          52, 23, 29, 24, 30,  0, 50, 45, 46,  0, 44,  0]])}
# {'reward': tensor([-648.6666]), 'log_likelihood': tensor([-14.1413], grad_fn=<SumBackward1>), 'actions': tensor([[29, 30, 47,  7, 37, 23, 11, 38,  8, 15, 25, 16, 45, 41,  5, 42,  6, 49,
#          50,  0, 43, 53, 59, 19, 57, 51, 60, 20, 58, 21, 26, 22,  0, 55,  9, 13,
#          31, 17, 14, 10, 48, 18,  3, 33, 27, 12,  4, 46,  0, 44, 54, 52, 56, 32,
#          35, 36, 34,  0, 24,  0, 28,  1,  2,  0, 39, 40,  0]])}
# {'reward': tensor([-545.6667]), 'log_likelihood': tensor([-17.8155], grad_fn=<SumBackward1>), 'actions': tensor([[51, 52,  5, 17,  6, 11, 37, 57, 38, 12, 47,  3, 15,  4, 39, 31, 23, 32,
#          40, 45, 53,  7, 54, 46, 24, 13,  8,  0, 18, 49, 35, 41, 59,  1, 27,  2,
#          36, 55, 48, 56,  9, 10,  0, 19, 25, 29, 20, 26, 30, 33, 21, 58, 34, 22,
#           0, 60, 42, 28, 43, 44,  0, 50, 16, 14,  0]])}
# {'reward': tensor([-537.6167]), 'log_likelihood': tensor([-12.8318], grad_fn=<SumBackward1>), 'actions': tensor([[19, 20, 27, 28, 15, 16, 41, 42, 51, 53,  3, 52,  7, 23, 47, 29,  4, 48,
#          30,  9,  5,  6, 25, 26,  0,  1,  2, 43, 55, 33, 56,  0, 45, 44, 46, 31,
#          21, 39, 17, 22, 40, 49, 18, 50, 13, 59, 14, 35, 24, 37, 36, 38, 10,  0,
#          34, 60,  8,  0, 11, 12, 57, 58, 54,  0, 32,  0]])}
# {'reward': tensor([-692.1667]), 'log_likelihood': tensor([-11.7499], grad_fn=<SumBackward1>), 'actions': tensor([[ 1, 33, 59, 11, 60,  2, 45, 53,  7, 46,  8, 54, 51, 13, 14,  0, 34, 57,
#          27, 39, 15, 19, 58, 29, 47, 16, 48,  9, 23, 10,  0, 25, 17, 43, 37, 18,
#          44, 30,  3,  4, 21, 35, 55, 36, 22,  5,  6,  0, 12, 26, 40, 41, 42, 31,
#          32,  0, 28, 56, 52, 24, 49, 50,  0, 20, 38,  0]])}
# {'reward': tensor([-496.4167]), 'log_likelihood': tensor([-12.3515], grad_fn=<SumBackward1>), 'actions': tensor([[17, 18, 55, 56, 39,  3, 35,  4,  7, 47,  9, 40,  8, 31, 10, 48,  0, 59,
#          13, 43, 45, 44, 14, 11, 12, 32,  0, 60, 49,  1, 15, 37,  2, 57, 53, 19,
#          21, 33, 51, 54,  5,  6, 52, 36, 23, 24,  0, 46, 16, 41, 42, 25, 26,  0,
#          50, 38, 20, 22, 29, 34,  0, 58, 27, 28,  0, 30,  0]])}
# {'reward': tensor([-557.1000]), 'log_likelihood': tensor([-14.3692], grad_fn=<SumBackward1>), 'actions': tensor([[ 3, 13, 47, 25,  4, 26, 48, 14, 39, 33,  5, 55, 27,  6, 40, 28, 56, 11,
#          12,  0, 59, 41, 57, 51,  7, 42,  8,  1, 17, 21, 31, 15,  2, 53, 16, 32,
#          49, 50, 34, 37, 45, 38, 43, 23, 44, 24,  0, 35, 29, 18, 22,  0, 60, 52,
#          30, 54, 19, 20, 46,  9, 10,  0, 58, 36,  0]])}
# {'reward': tensor([-634.9166]), 'log_likelihood': tensor([-16.3458], grad_fn=<SumBackward1>), 'actions': tensor([[33, 23, 43, 59, 24, 34, 15,  5, 39, 53,  1, 47, 40, 54,  6,  2, 29,  9,
#          27, 49, 10, 51, 52, 21, 22, 19, 20, 17, 18,  3,  4, 45, 46,  0, 44, 50,
#          28, 55, 35, 56, 41, 36, 57, 42, 58,  0, 60, 13, 31, 11,  7, 32, 14,  8,
#          12, 25, 26,  0, 48, 30, 37, 38,  0, 16,  0]])}
# {'reward': tensor([-652.8000]), 'log_likelihood': tensor([-12.7729], grad_fn=<SumBackward1>), 'actions': tensor([[ 9, 21, 33, 10, 34, 47, 11, 48, 12, 35, 37, 17, 18, 15, 23, 51, 24, 16,
#          52,  0, 22, 25, 59, 26, 27, 55,  5,  7, 19,  6,  8, 49, 43,  1, 50,  2,
#          44, 36, 53, 45, 13, 57, 54, 14, 46, 58, 29, 30,  0, 41, 39, 31, 40, 32,
#          38,  3,  4,  0, 60, 28,  0, 56, 42, 20,  0]])}
# {'reward': tensor([-676.4500]), 'log_likelihood': tensor([-9.0656], grad_fn=<SumBackward1>), 'actions': tensor([[ 9,  1, 37, 33, 49, 55, 35,  2, 57, 43, 56, 59, 58, 44,  5, 25,  6, 26,
#          45,  7, 46,  8, 53, 47, 54, 31, 48, 32, 41, 42,  0, 27, 29, 21, 23, 13,
#          15, 22, 60, 14, 39,  3,  4, 51, 52, 17, 18,  0, 34, 16, 19, 20, 40,  0,
#          10, 38, 36, 50, 30, 28, 24, 11, 12,  0]])}
# {'reward': tensor([-543.6333]), 'log_likelihood': tensor([-17.1507], grad_fn=<SumBackward1>), 'actions': tensor([[19, 31, 13, 37, 51, 14, 15, 33, 16, 34, 11, 25, 35, 49, 26,  0, 20, 32,
#          38, 52, 12, 50, 21,  9, 43, 22, 44, 45, 10, 53, 59, 46,  5, 54,  6, 41,
#          42,  0, 39, 40, 17, 55, 18, 36, 27,  3, 57, 47,  4, 48, 58, 29, 30, 23,
#          24,  0, 56, 28,  1,  2, 60,  7,  8,  0]])}
# {'reward': tensor([-617.6167]), 'log_likelihood': tensor([-8.2586], grad_fn=<SumBackward1>), 'actions': tensor([[11, 51, 12, 52, 43,  9, 57, 44, 10,  5, 55, 49, 13,  6, 15, 53, 37, 16,
#          54, 59, 25, 26, 31, 32,  0, 33, 21, 34, 17,  3, 22, 45,  4, 46, 18, 19,
#          47, 48, 20, 35, 36,  7,  8, 60, 23, 24,  0, 56, 14, 50, 39, 40, 38,  0,
#          58, 29, 30,  1, 27, 28,  2,  0, 41, 42,  0]])}
# {'reward': tensor([-607.7333]), 'log_likelihood': tensor([-12.3779], grad_fn=<SumBackward1>), 'actions': tensor([[ 1, 45, 29,  2, 46, 30, 51, 52, 39, 40, 13,  7, 55,  8, 56,  0, 23, 35,
#          49, 27, 17, 37, 50, 36, 18, 24, 19, 59, 20, 60, 21, 22, 53, 33, 41,  3,
#          54, 42,  4, 57, 25,  9, 15, 14, 26, 16, 10,  0, 28, 38, 47, 48, 58,  0,
#           5,  6, 43, 44,  0, 34, 11, 12,  0, 31, 32,  0]])}
# {'reward': tensor([-580.0500]), 'log_likelihood': tensor([-17.5108], grad_fn=<SumBackward1>), 'actions': tensor([[57, 35, 25, 13, 43, 33, 19, 26,  0, 36, 58, 14, 44, 20, 34, 27, 28,  9,
#          23, 10, 39, 40,  0, 21, 51, 53, 15, 52, 29, 16, 54,  7,  8, 37, 31, 59,
#           1, 32,  2, 60, 47,  3, 41, 17,  4, 42,  0, 22, 38, 24, 48, 49, 50,  0,
#          30, 11, 12,  0, 55, 18, 45,  5, 46,  6,  0, 56,  0]])}
# {'reward': tensor([-580.7667]), 'log_likelihood': tensor([-13.4732], grad_fn=<SumBackward1>), 'actions': tensor([[53, 35, 54, 36, 39, 43, 40, 11,  7, 45, 27, 12, 41,  8, 47, 51, 31, 42,
#          32, 52, 48,  0,  9, 15,  3, 33, 16,  4, 49, 17, 55, 18, 50, 44,  1, 19,
#           2, 28,  0, 10, 37, 23, 46, 38, 24,  0, 34, 56, 21, 22,  5, 13, 25, 57,
#           6, 26, 58, 20, 29, 30,  0, 59, 60,  0, 14,  0]])}
# {'reward': tensor([-512.1167]), 'log_likelihood': tensor([-12.9123], grad_fn=<SumBackward1>), 'actions': tensor([[25, 26, 47, 17,  1, 29,  2, 19, 20, 21,  5, 53, 59,  6, 23, 45, 24, 55,
#          56, 51, 52, 41, 42,  0, 43, 48, 18, 44, 46, 60,  0, 39,  9,  3, 10, 13,
#          15, 57,  4, 37, 35, 38,  0, 30, 40,  7,  8, 54,  0, 16, 49, 27, 50, 28,
#          11, 22,  0, 14, 58, 36, 12,  0, 31, 32, 33, 34,  0]])}
# {'reward': tensor([-440.7833]), 'log_likelihood': tensor([-11.2454], grad_fn=<SumBackward1>), 'actions': tensor([[25, 26,  1,  3, 21, 51, 55, 22,  2, 11, 23, 27, 52, 12, 28, 24, 29, 57,
#          13, 19, 30,  0,  4, 58, 43,  5, 31, 17, 47,  6, 18,  7,  8, 41, 49, 42,
#          53, 39, 54,  0, 37, 59, 45, 38, 14, 50,  9, 40, 10,  0, 56, 60, 46, 20,
#          44, 32, 48, 35, 33, 36, 34, 15, 16,  0]])}
# {'reward': tensor([-618.7001]), 'log_likelihood': tensor([-13.9579], grad_fn=<SumBackward1>), 'actions': tensor([[13, 35,  3, 57,  4,  9, 17, 37, 39, 29, 10, 18, 40, 41, 51, 53, 42, 54,
#           0, 14, 36, 33, 34, 30, 59, 25, 45,  7, 26,  8, 52,  0, 19,  1, 11, 21,
#           2, 20, 38, 43, 27,  5, 55,  6, 60, 47, 48,  0, 58, 49, 50, 23, 24,  0,
#          12, 22, 28, 56,  0, 44, 46, 15, 16,  0, 31, 32,  0]])}
# {'reward': tensor([-536.5500]), 'log_likelihood': tensor([-17.7170], grad_fn=<SumBackward1>), 'actions': tensor([[51, 17, 25, 43, 35, 39, 59, 21, 44, 18, 26, 40, 36, 31, 13, 23, 14,  3,
#          53, 55, 24, 41,  4,  1, 56, 29,  2, 30,  0, 52, 37, 57, 47,  9, 49, 38,
#          22, 10, 50, 11, 33, 12,  5,  6, 32, 45, 19, 46, 20,  7, 15,  8, 16,  0,
#          60, 58, 48, 54,  0, 34, 42,  0, 27, 28,  0]])}
# {'reward': tensor([-469.8833]), 'log_likelihood': tensor([-9.0224], grad_fn=<SumBackward1>), 'actions': tensor([[27, 28, 39, 47, 37, 53, 43, 35, 31, 44, 38, 36, 32, 59,  7, 60, 57,  8,
#          58, 17, 18, 51, 11, 49, 12, 50,  0, 40, 48, 54, 33, 45, 19,  5, 34, 46,
#          20, 52,  6,  0, 25,  1,  3, 55, 29, 21,  2,  9, 13, 10, 23, 41, 42, 24,
#           0, 15, 26,  0,  4, 16, 30, 22, 14,  0, 56,  0]])}
# {'reward': tensor([-583.1333]), 'log_likelihood': tensor([-13.4145], grad_fn=<SumBackward1>), 'actions': tensor([[23, 35, 59, 47, 24, 36, 60,  5,  6, 39, 11, 12, 51, 52, 49, 29, 30, 50,
#           0, 57,  3, 53, 43, 58,  4, 13, 37, 55, 27, 14, 56, 19,  9,  7, 15, 10,
#           8, 20, 16, 17, 21, 18, 31, 41, 40, 32,  0, 48, 45, 33, 46, 44,  0,  1,
#           2, 28, 22,  0, 25, 26, 38,  0, 34, 54, 42,  0]])}
# {'reward': tensor([-607.1000]), 'log_likelihood': tensor([-13.3847], grad_fn=<SumBackward1>), 'actions': tensor([[39, 35, 59, 19, 45, 51, 20, 52, 11, 27,  5, 28,  6, 23, 47, 57, 58,  3,
#           4, 31, 32,  7,  8,  9, 10, 49, 50,  0, 40, 60, 46, 24, 48, 37, 15, 29,
#          53, 30, 43, 21, 41, 16, 42, 25, 54, 44, 26,  0, 36, 12,  1, 17, 18,  2,
#          33, 34, 13, 14, 38, 22, 55, 56,  0]])}
# {'reward': tensor([-531.3833]), 'log_likelihood': tensor([-15.5109], grad_fn=<SumBackward1>), 'actions': tensor([[35, 29, 23, 59,  7, 49, 30,  1, 57,  2, 58, 19, 51, 41, 20, 53, 42, 52,
#          45, 25, 46, 26, 33, 34,  0,  8, 50, 43, 13, 27, 14, 54, 55, 56,  0, 24,
#          17,  9, 31,  3,  5, 47, 37, 11,  4, 48, 44, 28, 39, 40,  0, 60, 18, 32,
#          15, 16, 21, 22,  0, 36, 10,  0,  6, 38, 12,  0]])}
# {'reward': tensor([-552.1167]), 'log_likelihood': tensor([-14.2338], grad_fn=<SumBackward1>), 'actions': tensor([[13, 15, 57, 21, 37, 47, 14, 19,  9, 31, 10, 45, 46, 53, 54, 43, 44,  0,
#          58, 20, 38, 29, 39,  1, 30, 11,  3,  2, 40, 55, 56,  0, 16, 22, 32, 17,
#          59, 18, 33, 41,  7,  5,  6, 12,  4, 51, 52,  0, 48, 60, 25, 26,  0, 49,
#          23, 50,  0, 34,  8, 42,  0, 24, 27, 28,  0, 35, 36,  0]])}
# 100%|██████████| 60/60 [01:26<00:00,  1.44s/it]
# 100%|██████████| 5/5 [06:53<00:00, 82.76s/it]

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
reqs = 30

# Prepare data
trained_rewards = np.array(records[f"{reqs} req"]["neural"])
or_rewards = np.array(records[f"{reqs} req"]["or_tools"])


# ---- Filter out -inf values ----
mask = (trained_rewards != -np.inf) & (or_rewards != -np.inf)
trained_rewards = trained_rewards[mask]
or_rewards = or_rewards[mask]
# --------------------------------

# Create scatter plot
plt.figure(figsize=(8, 8))
plt.scatter(
    or_rewards,
    trained_rewards,
    alpha=0.6,
    s=100,
    color='#4c72b0',
    edgecolors='black',
    linewidth=0.5
)

# Add diagonal reference line
min_val = min(or_rewards.min(), trained_rewards.min())
max_val = max(or_rewards.max(), trained_rewards.max())
plt.plot(
    [0, max_val],
    [0, max_val],
    'r--',
    linewidth=2,
    label='(y=x)',
    alpha=0.7
)

# Labels and title
plt.xlabel("OR-Tools Reward", fontsize=20)
plt.ylabel("Neural Model Reward", fontsize=20)
plt.legend()
plt.grid(True, alpha=0.3)
plt.axis('equal')

# Mean optimality gap (only for valid points)
gap = np.mean((or_rewards - trained_rewards) / np.abs(or_rewards)) * 100
slope, intercept, r_value, p_value, std_err = stats.linregress(or_rewards, trained_rewards)
plt.title(f"Trained vs OR-Tools Rewards\n Average Gap: {gap:.2f}%  ({reqs} reqs), Linear Coef: {r_value:.3f} ",fontsize=20)

plt.tight_layout()
plt.show()

# %%
def check_pairwise_validity(seq: torch.Tensor) -> bool:
    """
    Check if every subroute (separated by 0) contains only valid (2i-1, 2i) pairs.
    A pair is valid if for every request i, either both nodes (2i-1 and 2i)
    appear together in the same slice or neither appears at all.
    """
    # Convert tensor to list
    arr = seq.tolist()
    # Split by 0
    slices = []
    cur = []
    for x in arr:
        if x == 0:
            if cur:
                slices.append(cur)
                cur = []
        else:
            cur.append(x)
    if cur:
        slices.append(cur)

    # Check each slice
    for s in slices:
        s_set = set(s)
        for i in range(1, (max(s) // 2) + 2):
            a, b = 2 * i - 1, 2 * i
            in_a, in_b = a in s_set, b in s_set
            if in_a ^ in_b:  # only one of them is present
                return False
    return True

check_pairwise_validity(actions_trained[0])
# Out:
# False

# %%
# Compare policy with untrained policy
check = False
while check == False: 
      
  # Testing: Greedy rollouts over trained model (same states as previous plot)
  env = PDPTWEnv(generator_params={"num_loc":30})
  td_init = env.reset(batch_size=[1]).to(device)

  out = policy(td_init.clone(), phase="test", decode_type="greedy", return_actions=True)
  actions_trained = out['actions'].cpu().detach()
  rewards_trained = out['reward']
  check = check_pairwise_validity(actions_trained[0])
  print(check, end='')
  

untrained_policy = AttentionModelPolicy(env_name=env.name, 
                              embed_dim=128,
                              num_encoder_layers=3,
                              num_heads=8
                            )

untrained_out = untrained_policy(td_init.clone(), phase="test", decode_type="greedy", return_actions=True)
actions_untrained = untrained_out['actions'].cpu().detach()
rewards_untrained = untrained_out['reward']



# Plotting
import matplotlib.pyplot as plt
for i, td in enumerate(td_init):
    fig, axs = plt.subplots(1,2, figsize=(11,5))
    env.render(td, actions_untrained[i], ax=axs[0]) 
    env.render(td, actions_trained[i], ax=axs[1])
    axs[0].set_title(f"Untrained | Cost = {-rewards_untrained[i].item():.3f}")
    axs[1].set_title(r"Trained $\pi_\theta$" + f"| Cost = {-out['reward'][i].item():.3f}")

print(actions_trained)
# Out:
# /Users/jiangwolin/Desktop/Research/llm-rl/rl4co/rl4co/envs/routing/cvrptw/env.py:186: RuntimeWarning: vehicle cannot perform service and get back to depot in time.
#   warnings.warn(
# /Users/jiangwolin/Desktop/Research/llm-rl/rl4co/rl4co/envs/routing/cvrptw/env.py:215: RuntimeWarning: vehicle cannot start service before deadline
#   warnings.warn(
# FalseFalseFalseFalseFalseFalseFalseFalseFalseFalseFalseFalseFalseFalseFalseFalseFalseFalseFalse
# /Users/jiangwolin/Desktop/Research/llm-rl/rl4co/rl4co/envs/routing/cvrp/env.py:191: RuntimeWarning: Used more than capacity
#   warnings.warn("Used more than capacity", RuntimeWarning)
# ...([[ 1, 17,  2, 18,  3, 13,  4, 14,  0, 15, 29, 30, 23, 27, 16, 19, 24, 28,
#          20,  7, 11,  8, 12,  0,  9, 21,  5, 22, 10, 25,  6, 26]])
